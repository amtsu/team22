# %% [markdown]
# # Отрабатываем работу с файлами

# %% [markdown]
# Продолжаем расширять функционал нашего телефонного справочника.
# Наша задача реализовать возможность сохранения данных справочника на диск, с последующим восстанволением его с диска и продолжением работы с ним.

# %% [markdown]
# ### Способ использования:
# Я как пользователь использующий програму телефоный справочник. Хочу иметь возможность добалять в справочник новые контакты, искать контакты в справочнике по имени, номеру теелфона, городу и увлечениям, удалять конаткты из справоника а таже быть уверенным что после закрытия программы контакты не потеряются и я смогу продолжить с ним работу.

# %% [markdown]
# ### Условия

# %% [markdown]
# Желательно придумать несколько способов сохранения справочника(миниму 2).

# %% [markdown]
# Формат данных который можно использовать для спарвочника:

# %%
phone_book = [
    {
        'phone': '+79165556688',
        'city': 'Ulitsa lenina d 1',
        'name': 'Artem',
        'year': 1912,
        'hobby': ['sport', 'programming']
    },
]

# %% [markdown]
# # Варинат с использованием библиотеки pickle
# Подготовка:
# 1. Создать телефонный справочник содержащий минимум три контакта, какждый контакт может иметь следующие параметры: имя, город, телефон, хобби(список из 3 элементов), возраст(число).
# 2. Сохранить в файл с помощью функций библиотеки pickle.
#
# Основной этап:
# 1. Загрузить телефонный справочник который лежит в файле "название_файла"
# 2. Найти все контакты в справочники у котого есть хобби программирование и кто старже 22 лет. Для этого нужно будет написать функции.
# 3. Затем добавить в справочник еще один контакт: Программист Вася +7916-222-33-44 27лет.
# 4. Проверить что вернет функция из 2 шага.
# 5. Вывести весь список контактов отсортированный по возратсу.
# 6. Сохранить изменния справочника на диск.
