# %% [raw]
# Часть 1: Основы
#
# • Понятие Интернета
#     * История и эволюция Интернета
#     * Глобальная сеть взаимосвязанных компьютерных сетей
# • Архитектура Интернета
#     * Уровневая модель (физический, канальный, сетевой, транспортный, сеансовый, презентационный, прикладной)
#     * Протоколы и стандарты (TCP/IP, HTTP, DNS)
# • Браузеры и их функции
#     * Типы браузеров (Chrome, Firefox, Safari)
#     * Основные функции браузеров (отображение веб-страниц, обработка запросов HTTP, выполнение JavaScript)
# • Серверы и их типы
#     * Веб-серверы (Apache, Nginx)
#     * Почтовые серверы (SMTP, POP3, IMAP)
#     * Базы данных (MySQL, PostgreSQL)
#
# Часть 2: Передача данных
#
# • Пакеты и протоколы
#     * Понятие пакета данных
#     * Протоколы как правила передачи данных
# • Протокол TCP/IP
#     * Транспортный протокол для передачи данных в Интернете
#     * Работа с сегментами и подтверждениями
# • HTTP и HTTPS
#     * Протокол прикладного уровня для передачи гипертекста
#     * Обеспечение защищенного соединения с использованием HTTPS
#
# Часть 3: Создание HTML-страницы
#
# • Основные теги и структура HTML
#     * Теги заголовков, абзацев, списков
#     * Структура документа HTML (head, body)
# • Создание простой HTML-страницы
#     * Использование текстового редактора или онлайн-инструмента
#     * Написание HTML-кода для отображения заголовка, текста и изображения
# • Подключение CSS и JavaScript
#     * Использование CSS для стилизации HTML-страницы
#     * Использование JavaScript для добавления интерактивности
#
# Часть 4: Отдача страницы по протоколу HTTP
#
# • Настройка локального веб-сервера
#     * Использование Apache или Nginx
#     * Настройка корневого каталога и портов
# • Настройка маршрутизации запросов HTTP
#     * Использование файлов конфигурации сервера (например, .htaccess)
#     * Настройка маршрутов для обработки запросов к конкретным файлам
# • Отправка ответа HTTP с HTML-страницей
#     * Создание обработчика запросов
#     * Отправка заголовков и содержимого HTML-страницы
#
# Практическое задание
#
# • Создание простой HTML-страницы
#     * Использование предоставленного шаблона или самостоятельное написание HTML-кода
# • Настройка локального веб-сервера
#     * Следование инструкциям по установке и настройке веб-сервера
# • Отправка запроса HTTP
#     * Использование браузера или инструмента командной строки (например, curl)
# • Получение HTML-страницы в браузере
#     * Просмотр и взаимодействие с HTML-страницей
#
# Вопросы и обсуждение
#
# • Обсуждение концепций и практического задания
# • Ответы на вопросы
# • Дополнительные темы для обсуждения (например, безопасность Интернета, будущее Интернета)

# %% [raw]
# Основы Интернета
#
# Введение
#
# Интернет стал неотъемлемой частью нашей жизни, предоставляя доступ к информации, развлечениям и общению. Чтобы эффективно использовать Интернет, необходимо понять его основные концепции, архитектуру и компоненты.
#
# История и эволюция Интернета
#
# Интернет возник в 1969 году как исследовательский проект под названием ARPANET. Он был разработан для обеспечения связи между компьютерами разных университетов и исследовательских центров. Первоначально ARPANET использовал протокол NCP (Network Control Protocol), но позже перешел на более совершенный протокол TCP/IP (Transmission Control Protocol/Internet Protocol).
#
# В 1983 году был предложен домен верхнего уровня (TLD) .com для коммерческих организаций, что ознаменовало начало коммерческого использования Интернета. В 1990-х годах Всемирная паутина (WWW) сделала Интернет доступным для широкой публики, поскольку она позволяла пользователям просматривать веб-страницы с помощью графического интерфейса.
#
# Глобальная сеть взаимосвязанных компьютерных сетей
#
# Интернет - это глобальная сеть, которая соединяет миллиарды компьютеров, ноутбуков, планшетов и смартфонов по всему миру. Эти устройства подключены друг к другу через различные типы сетей, включая проводные, беспроводные и спутниковые.
#
# Архитектура Интернета
#
# Архитектура Интернета основана на уровневой модели, которая разделяет сетевые функции на семь уровней:
#
# • Физический: Передача данных по физическим средам, таким как кабели или оптоволокно.
# • Канальный: Управление доступом к среде передачи данных.
# • Сетевой: Определение маршрута данных через сеть.
# • Транспортный: Обеспечение надежной передачи данных между хостами.
# • Сеансовый: Управление сеансами взаимодействия между приложениями.
# • Презентационный: Форматирование данных для разных приложений.
# • Прикладной: Предоставление пользовательских сервисов, таких как веб-браузинг и электронная почта.
#
# Протоколы и стандарты
#
# Для обеспечения бесперебойной работы Интернета используются различные протоколы и стандарты. Два основных протокола - TCP/IP и HTTP:
#
# • TCP/IP (Transmission Control Protocol/Internet Protocol): Комплект протоколов, используемых для передачи данных через Интернет. TCP гарантирует надежную доставку данных, а IP обеспечивает адресацию устройств.
# • HTTP (Hypertext Transfer Protocol): Протокол, используемый для передачи веб-страниц между браузерами и веб-серверами.
#
# Браузеры и их функции
#
# Браузеры - это программное обеспечение, которое позволяет пользователям получать доступ к веб-страницам в Интернете. Основные функции браузеров включают:
#
# • Отображение веб-страниц, написанных на HTML (Hypertext Markup Language) и CSS (Cascading Style Sheets).
# • Обработка запросов HTTP и отправка их на соответствующие веб-серверы.
# • Выполнение JavaScript, языка программирования, который используется для создания интерактивных веб-страниц.
#
# Серверы и их типы
#
# Серверы - это компьютеры, которые предоставляют услуги другим компьютерам или устройствам. Существует множество типов серверов, каждый из которых выполняет определенную функцию:
#
# • Веб-серверы (Apache, Nginx): Хранят и обслуживают веб-контент, такой как веб-страницы, изображения и видео.
# • Почтовые серверы (SMTP, POP3, IMAP): Отправляют, получают и хранят электронные письма.
# • Базы данных (MySQL, PostgreSQL): Хранят и управляют структурированными данными, используемыми приложениями и веб-сайтами.

# %%
a1 -> b1 : Hello Vasy
tpc: 00010,ghghdfh,Hello Vasy = z1
ip: a1,b1,z1 : a1,b1,00010,ghghdfh,Hello Vasy = z2
c: mac,...,z2

c: 
браузер:
комилятор кода
визуализацию
доступ к файл по ип адресу
сам отраляет запросы (get, post

# %% [raw]
# Уровневая модель
#
# Как упоминалось ранее, архитектура Интернета основана на уровневой модели, которая делит сетевые функции на семь уровней:
#
# 1. Физический уровень:
#
# • Передача данных по физическим средам, таким как медные кабели, оптоволоконные кабели и беспроводные сигналы.
# • Охватывает сетевые интерфейсные карты, модемы, маршрутизаторы и коммутаторы.
#
# 2. Канальный уровень:
#
# • Управляет доступом к среде передачи данных.
# • Реализует протоколы контроля доступа к среде, такие как Ethernet и Wi-Fi.
#
# 3. Сетевой уровень:
#
# • Определяет маршрут данных через сеть.
# • Использует протоколы маршрутизации, такие как IP (Internet Protocol) и BGP (Border Gateway Protocol).
#
# 4. Транспортный уровень:
#
# • Обеспечивает надежную передачу данных между хостами.
# • Использует протоколы, такие как TCP (Transmission Control Protocol) и UDP (User Datagram Protocol).
#
# 5. Сеансовый уровень:
#
# • Управляет сеансами взаимодействия между приложениями.
# • Использует протоколы, такие как TCP и UDP, для установления, поддержания и завершения сеансов.
#
# 6. Презентационный уровень:
#
# • Форматирует данные для разных приложений.
# • Обеспечивает преобразование данных между различными форматами, такими как ASCII и EBCDIC.
#
# 7. Прикладной уровень:
#
# • Предоставляет пользовательские сервисы, такие как веб-браузинг, электронная почта и передача файлов.
# • Использует протоколы, такие как HTTP (Hypertext Transfer Protocol), SMTP (Simple Mail Transfer Protocol) и FTP (File Transfer Protocol).
#
# Протоколы и стандарты
#
# Два наиболее важных протокола, используемых в Интернете, это TCP/IP и HTTP:
#
# • TCP/IP (Transmission Control Protocol/Internet Protocol): Комплект протоколов, который формирует основу Интернета. TCP обеспечивает надежную доставку данных, разбивая данные на пакеты и гарантируя их доставку в правильном порядке. IP обеспечивает адресацию устройств, присваивая каждому устройству уникальный IP-адрес.
# • HTTP (Hypertext Transfer Protocol): Протокол, используемый для передачи веб-страниц между браузерами и веб-серверами. HTTP определяет, как браузеры запрашивают веб-страницы и как веб-серверы отвечают на эти запросы.
#
# Помимо TCP/IP и HTTP, существует множество других протоколов и стандартов, которые используются в Интернете, каждый из которых выполняет определенную функцию. Например, DNS (Domain Name System) преобразует доменные имена в IP-адреса, а SMTP (Simple Mail Transfer Protocol) используется для отправки и получения электронных писем.
#
# Как работает Интернет
#
# Чтобы понять, как работает Интернет, давайте рассмотрим пример того, как вы просматриваете веб-страницу:
#
# 1. Вы вводите URL-адрес в браузере.
# 2. Ваш компьютер отправляет запрос DNS-серверу для преобразования доменного имени в IP-адрес.
# 3. Ваш компьютер устанавливает TCP-соединение с веб-сервером по IP-адресу.
# 4. Ваш компьютер отправляет запрос HTTP на веб-сервер, запрашивая веб-страницу.
# 5. Веб-сервер обрабатывает запрос и отправляет обратно ответ HTTP, содержащий веб-страницу.
# 6. Ваш браузер получает ответ и отображает веб-страницу на вашем устройстве.
#
# Маршрутизация и адресация
#
# Помимо передачи данных, Интернет также использует маршрутизацию и адресацию для обеспечения доставки данных по назначению:
#
# • Маршрутизация: Процесс определения наилучшего пути для передачи данных через сеть. Маршрутизаторы используют таблицы маршрутизации для определения следующего перехода для пакета данных.
# • Адресация: Схема присвоения уникальных идентификаторов устройствам, подключенным к сети. IP-адреса используются для идентификации устройств в Интернете, а MAC-адреса используются для идентификации устройств в локальных сетях.

# %%
# !ifconfig
# Out:
# br-1a978bc78000: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 192.168.48.1  netmask 255.255.240.0  broadcast 192.168.63.255
#         inet6 fe80::42:27ff:fe3c:caea  prefixlen 64  scopeid 0x20<link>
#         ether 02:42:27:3c:ca:ea  txqueuelen 0  (Ethernet)
#         RX packets 6738  bytes 11926214 (11.9 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 7864  bytes 1376899 (1.3 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# docker0: flags=4099<UP,BROADCAST,MULTICAST>  mtu 1500
#         inet 172.17.0.1  netmask 255.255.0.0  broadcast 172.17.255.255
#         inet6 fe80::42:aff:fe94:4277  prefixlen 64  scopeid 0x20<link>
#         ether 02:42:0a:94:42:77  txqueuelen 0  (Ethernet)
#         RX packets 15435  bytes 1095566 (1.0 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 23224  bytes 104623118 (104.6 MB)
# ...

# %%
# !ping  94.250.254.32
# Out:
# PING 94.250.254.32 (94.250.254.32) 56(84) bytes of data.
# 64 bytes from 94.250.254.32: icmp_seq=1 ttl=64 time=0.100 ms
# 64 bytes from 94.250.254.32: icmp_seq=2 ttl=64 time=0.058 ms
# 64 bytes from 94.250.254.32: icmp_seq=3 ttl=64 time=0.066 ms
# 64 bytes from 94.250.254.32: icmp_seq=4 ttl=64 time=0.080 ms
# 64 bytes from 94.250.254.32: icmp_seq=5 ttl=64 time=0.063 ms
# 64 bytes from 94.250.254.32: icmp_seq=6 ttl=64 time=0.054 ms
# 64 bytes from 94.250.254.32: icmp_seq=7 ttl=64 time=0.070 ms
# ^C
#
# --- 94.250.254.32 ping statistics ---
# 7 packets transmitted, 7 received, 0% packet loss, time 6147ms
# rtt min/avg/max/mdev = 0.054/0.070/0.100/0.014 ms

# %%
# !tracert 94.250.254.32
# Out:
# /bin/bash: tracert: command not found

# %% [raw]
# Передача Данных
#
# Пакеты и Протоколы
#
# Понятие Пакет Данных
#
# Пакет данных представляет собой единицу данных, которая передается по сети. Он содержит заголовок, содержащий информацию о отправителе, получателе и другом, а также полезную нагрузку, содержащую фактические данные. Разделение данных на пакеты позволяет разбить большие файлы на более мелкие фрагменты, что облегчает их передачу и обработку.
#
# Протоколы как Правила Передачи Данных
#
# Протоколы - это набор правил, которые управляют передачей данных между устройствами в сети. Они определяют, как пакеты структурируются, адресуются и маршрутизируются, а также как обрабатываются ошибки. Без протоколов устройства не могли бы понимать друг друга и обмениваться данными.
#
# Протокол TCP/IP
#
# Транспортный Протокол для Передачи Данных в Интернете
#
# TCP/IP (Transmission Control Protocol/Internet Protocol) - это семейство протоколов, которое формирует основу Интернета. Он обеспечивает надежную, двустороннюю передачу данных между хостами в сети. TCP (Транспортный протокол управления передачей) отвечает за сегментацию данных на пакеты, установление соединений и подтверждение доставки. IP (Интернет-протокол) отвечает за адресацию и маршрутизацию пакетов.
#
# Работа с Сегментами и Подтверждениями
#
# TCP сегментирует данные на пакеты, каждое из которых имеет последовательный номер. После отправки пакета TCP ожидает подтверждения от получателя, что подтверждает успешную доставку. Если подтверждение не получено, пакет отправляется повторно. Этот механизм обеспечения надежности гарантирует, что данные будут доставлены без ошибок.
#
# HTTP и HTTPS
#
# Протокол Прикладного Уровня для Передачи Гипертекста
#
# HTTP (Протокол передачи гипертекста) - это протокол прикладного уровня, который используется для передачи гипертекстовых документов, таких как веб-страницы, между веб-серверами и клиентами. Он определяет, как запросы и ответы структурируются и обрабатываются. HTTPS (Протокол защищенной передачи гипертекста) - это версия HTTP, которая обеспечивает безопасное соединение между клиентом и сервером, используя шифрование для защиты данных в пути.
#
# Обеспечение Защищенного Соединения с Использованием HTTPS
#
# HTTPS использует протокол TLS (Transport Layer Security) или его преемника, SSL (Secure Sockets Layer), для шифрования данных перед передачей. Это предотвращает перехват и просмотр данных злоумышленниками, обеспечивая конфиденциальность и целостность информации. HTTPS широко используется на веб-сайтах, требующих безопасного обмена данными, таких как онлайн-банкинг и торговля.

# %% [raw]
# Создание HTML-Страниц
#
# Основные Теги и Структура HTML
#
# Теги Заголовков, Абзацев, Списков
#
# HTML-теги - это ключевые слова, которые определяют различную структуру и содержание веб-страницы. Основные теги включают:
#
# * Теги заголовков (<h1>, <h2>, ...<h6>): Определяют заголовки разного размера
# * Тег абзаца (<p>): Определяет абзац текста
# * Теги списка (<ul>, <ol>): Определяют неупорядоченные и упорядоченные списки
#
# Структура Документа HTML (head, body)
#
# HTML-документ имеет следующую структуру:
#
# * Head: Содержит информацию о странице, такую как заголовок, метаданные и ссылки на внешние ресурсы
# * Body: Содержит основное содержимое страницы, такое как текст, изображения и другие элементы
#
# Создание Простой HTML-Страницы
#
# Использование Текстового Редактора или Онлайн-Инструмента
#
# Для создания HTML-страниц можно использовать любой текстовый редактор, такой как Блокнот или Sublime Text. Также существуют онлайн-инструменты, такие как W3Schools Online HTML Editor, которые позволяют создавать и редактировать HTML-код в браузере.
#
# Написание HTML-Кода для Отображения Заголовка, Текста и Изображения
#
# Следующий HTML-код создаст простую страницу с заголовком, абзацем текста и изображением:

# %%
<!DOCTYPE html>
<html>
<head>
  <title>Моя Первая HTML Страница</title>
</head>
<body>
  <h1>Заголовок Страницы</h1>
  <p>Привет, мир! Это моя первая HTML-страница.</p>
  <img src="image.jpg" alt="Изображение">
</body>
</html>
# Out:
#   Cell In[2], line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %% [raw]
# Подключение CSS и JavaScript
#
# Использование CSS для Стилизации HTML-Страницы
#
# CSS (Cascading Style Sheets) - это язык стилей, который позволяет стилизовать HTML-страницы. Он используется для управления такими элементами, как цвета, шрифты, расположение и другие визуальные аспекты. CSS подключается к HTML-документу с помощью тега <link>:

# %%
<link rel="stylesheet" href="style.css">
# Out:
#   Cell In[3], line 1
#     <link rel="stylesheet" href="style.css">
#     ^
# SyntaxError: invalid syntax

# %% [raw]
# Использование JavaScript для Добавления Интерактивности
#
# JavaScript - это язык программирования, который используется для добавления интерактивности на веб-страницы. Он позволяет создавать динамические эффекты, такие как выпадающие меню, всплывающие окна и валидация форм. JavaScript подключается к HTML-документу с помощью тега <script>:

# %%
<script src="script.js"></script>
# Out:
#   Cell In[4], line 1
#     <script src="script.js"></script>
#     ^
# SyntaxError: invalid syntax
