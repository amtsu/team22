# %%
# Линенйная регрессия

# полдучить проданные крвартиры
# построить регресию от параметрв () как бейзлайн (а пока средене)
            "title": "Причальный Юг 3 72.8 Причальный пр., д. 8 55.76018,37.517482",
            "price": "61182068.00",
            "price_sale": "42827447.00",
            "datetime_create": "2023-02-11T00:04:27.136984Z",
            "category": "Новостройки",
            "brand": "level.ru",
            "brand_url": "level.ru",
            "description": "[{\"name\": \"\\u041f\\u0410\\u041e \\u00ab\\u0421\\u043e\\u0432\\u043a\\u043e\\u043c\\u0431\\u0430\\u043d\\u043a\\u00bb. \\u0421\\u0442\\u0430\\u0432\\u043a\\u0430 \\u043f\\u043e \\u043a\\u0440\\u0435\\u0434\\u0438\\u0442\\u0443 7,1%, \\u043f\\u0435\\u0440\\u0432\\u043e\\u043d\\u0430\\u0447\\u0430\\u043b\\u044c\\u043d\\u044b\\u0439 \\u0432\\u0437\\u043d\\u043e\\u0441 \\u043e\\u0442 20%, \\u0441\\u0440\\u043e\\u043a \\u043a\\u0440\\u0435\\u0434\\u0438\\u0442\\u043e\\u0432\\u0430\\u043d\\u0438\\u044f \\u0434\\u043e 30 \\u043b\\u0435\\u0442, \\u0441\\u0443\\u043c\\u043c\\u0430 \\u043a\\u0440\\u0435\\u0434\\u0438\\u0442\\u0430 \\u0431\\u0435\\u0437 \\u043e\\u0433\\u0440\", \"discount_percent\": null, \"discount_sum\": null, \"amount\": null, \"term\": 360, \"deposit\": 20.0, \"mortgage_percent\": 7.1, \"is_base_price\": null, \"readable_sale_type\": null, \"sale_type\": null, \"sale_type_name\": null}, {\"name\": \"30% (100%, \\u0440\\u0430\\u0441\\u0441\\u0440\\u043e\\u0447\\u043a\\u0430, \\u043d\\u0435\\u0441\\u0443\\u0431\\u0441\\u0438\\u0434\\u0438\\u0440\\u043e\\u0432\\u0430\\u043d\\u043d\\u0430\\u044f \\u0438\\u043f\\u043e\\u0442\\u0435\\u043a\\u0430)\", \"discount_percent\": 30.0, \"discount_sum\": null, \"amount\": null, \"term\": null, \"deposit\": null, \"mortgage_percent\": null, \"is_base_price\": null, \"readable_sale_type\": \"100% \\u043e\\u043f\\u043b\\u0430\\u0442\\u0430\", \"sale_type\": 1, \"sale_type_name\": \"\\u041e\\u0441\\u043d\\u043e\\u0432\\u043d\\u0430\\u044f\"}, {\"name\": \"15% (\\u0421\\u0443\\u0431\\u0441\\u0438\\u0434\\u0438\\u0440\\u043e\\u0432\\u0430\\u043d\\u043d\\u0430\\u044f \\u0438\\u043f\\u043e\\u0442\\u0435\\u043a\\u0430)\", \"discount_percent\": 15.0, \"discount_sum\": null, \"amount\": null, \"term\": null, \"deposit\": null, \"mortgage_percent\": null, \"is_base_price\": null, \"readable_sale_type\": \"\\u0414\\u043b\\u044f \\u0438\\u043f\\u043e\\u0442\\u0435\\u043a\\u0438\", \"sale_type\": 2, \"sale_type_name\": \"\\u0421\\u0443\\u0431\\u0441\\u0438\\u0434\\u0438\\u0440\\u043e\\u0432\\u0430\\u043d\\u043d\\u0430\\u044f\"}, {\"name\": \"\\u0410\\u041e \\u00ab\\u0410\\u043b\\u044c\\u0444\\u0430-\\u0411\\u0430\\u043d\\u043a\\u00bb. \\u0421\\u0442\\u0430\\u0432\\u043a\\u0430 \\u043f\\u043e \\u043a\\u0440\\u0435\\u0434\\u0438\\u0442\\
\u043a\\u0440\\u0435\\u0434\\u0438\\u0442\\u0430 \\u0431\\u0435\\u0437 \\u043e\\u0433\\u0440\\u0430\\u043d\\u0438\\u0447\\u0435\\u043d\\u0438\\u044f\", \"discount_percent\": -15.0, \"discount_sum\": null, \"amount\": \"0.00\", \"term\": 360, \"deposit\": 15.0, \"mortgage_percent\": 3.0, \"is_base_price\": null, \"readable_sale_type\": null, \"sale_type\": null, \"sale_type_name\": null}, {\"name\": \"\\u0410\\u041e \\u00ab\\u0411\\u0430\\u043d\\u043a \\u0414\\u041e\\u041c.\\u0420\\u0424\\u00bb.\\u041a\\u043e\\u043c\\u0431\\u043e \\u0438\\u043f\\u043e\\u0442\\u0435\\u043a\\u0430 \\u0434\\u043b\\u044f IT-\\u0441\\u043f\\u0435\\u0446\\u0438\\u0430\\u043b\\u0438\\u0441\\u0442\\u043e\\u0432. \\u0421\\u0443\\u043c\\u043c\\u0430 \\u043a\\u0440\\u0435\\u0434\\u0438\\u0442\\u0430 \\u043e\\u0442 18 \\u0434\\u043e 30 \\u043c\\u043b\\u043d. \\u0440\\u0443\\u0431. \\u0421\\u0442\\u0430\\u0432\\u043a\\u0430 \\u043f\\u043e \\u043a\\u0440\\u0435\\u0434\\u0438\\u0442\\u0443 4,5%, \\u043f\\u0435\\u0440\\u0432\\u043e\\u043d\\u0430\\u0447\\u0430\\u043b\\u044c\\u043d\\u044b\\u0439 \\u0432\\u0437\\u043d\\u043e\\u0441 \\u043e\\u0442 15%, \\u0441\\u0440\\u043e\\u043a \\u043a\\u0440\\u0435\\u0434\\u0438\\u0442\\u043e\\u0432\\u0430\\u043d\\u0438\\u044f \\u0434\\u043e 30 \\u043b\\u0435\\u0442\", \"discount_percent\": null, \"discount_sum\": null, \"amount\": \"30000000.00\", \"term\": 360, \"deposit\": 15.0, \"mortgage_percent\": 4.5, \"is_base_price\": null, \"readable_sale_type\": null, \"sale_type\": null, \"sale_type_name\": null}]",
            "source_url": "https://level.ru/api/flat/?limit=8&offset=1096",

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import sqlite3
import json

# Сброс ограничений на количество выводимых рядов
pd.set_option('display.max_rows', None)
 
# Сброс ограничений на число столбцов
pd.set_option('display.max_columns', None)
 
# Сброс ограничений на количество символов в записи
pd.set_option('display.max_colwidth', None)

# %%
#connection = sqlite3.connect('/tmp/sql_dump/db.sqlite3')
connection = sqlite3.connect('/home/jupyter-amtsu/project/price_alert/db.sqlite3')
cursor = connection.cursor()

# %%
df2 = pd.DataFrame([['Earth', 1], ['Moon', 0.606], ['Mars', 0.107]])

# %%
df2
# Out:
#        0      1
# 0  Earth  1.000
# 1   Moon  0.606
# 2   Mars  0.107

# %%
#5196982
#5193646
cursor.execute("""
select 
count(1)
from products_history 
limit 100
""")
cursor.fetchall()

# %%
#66039
#2211
#1104
#3297
#3336
cursor.execute("""
select 
count(1)
from products_history 
where source_url like "%level.ru%"
 and datetime_create > "2023-02-11"
limit 1000
""")
cursor.fetchall()

# %%
cursor.execute("""
select 
count(*)
from products_history 
where (
    source_url like "%fr.mos.ru%"
    --or 
    --source_url like "%level.ru%"
 )
 and datetime_create > "2023-02-11"
 order by id desc
limit 300
""")
cursor.fetchall()
#3028
#3343

# %%
cursor.execute("""
select 
*
from products_history 
where (
    source_url like "%fr.mos.ru%"
    --or 
    --source_url like "%level.ru%"
 )
 and datetime_create > "2023-02-11"
 order by id desc
limit 300
""")
cursor.fetchall()

# %%
#cursor.execute("""
#delete
#from products_history 
#where source_url like "%level.ru%"
# and datetime_create > "2023-02-11"
#""")
#cursor.fetchall()

# %%
#connection.commit()

# %%
cursor.execute("""
select 
    title,
    price,
    price_sale,
    datetime_create,
    category,
    --brand,
    --brand_url,
    --description,
    source_url,
    apartment_area,
    apartment_completion_quarter,
    apartment_completion_year,
    apartment_floor,
    apartment_floors_total,
    apartment_ceilingheight,
    apartment_room,
    apartment_ppm,
    apartment_address,
    apartment_location_lat,
    apartment_location_lon
    
from products_history 
where url like "%level.ru%"
   and price_sale < 100000000
order by datetime_create desc
limit 100
""")
#cursor.fetchall()

df = pd.DataFrame(cursor.fetchall(), columns=[
    "title",
    "price",
    "price_sale",
    "datetime_create",
    "category",
    "source_url",
    "apartment_area",
    "apartment_completion_quarter",
    "apartment_completion_year",
    "apartment_floor",
    "apartment_floors_total",
    "apartment_ceilingheight",
    "apartment_room",
    "apartment_ppm",
    "apartment_address",
    "apartment_location_lat",
    "apartment_location_lon",
])

# %%
#title, datetime_create, category, source_url, apartment_address

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         100 non-null    object
#  1   price                         100 non-null    int64
#  2   price_sale                    100 non-null    int64
#  3   datetime_create               100 non-null    object
#  4   category                      100 non-null    object
#  5   source_url                    100 non-null    object
#  6   apartment_area                100 non-null    float64
#  7   apartment_completion_quarter  100 non-null    int64
#  8   apartment_completion_year     100 non-null    int64
#  9   apartment_floor               100 non-null    int64
#  10  apartment_floors_total        92 non-null     float64
#  11  apartment_ceilingheight       92 non-null     float64
#  12  apartment_room                100 non-null    int64
#  13  apartment_ppm                 100 non-null    int64
#  14  apartment_address             100 non-null    object
#  15  apartment_location_lat        100 non-null    float64
#  16  apartment_location_lon        100 non-null    float64
# dtypes: float64(5), int64(7), object(5)
# memory usage: 13.4+ KB

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         92 non-null     object
#  1   price                         92 non-null     int64
#  2   price_sale                    92 non-null     int64
#  3   datetime_create               92 non-null     object
#  4   category                      92 non-null     object
#  5   source_url                    92 non-null     object
#  6   apartment_area                92 non-null     float64
#  7   apartment_completion_quarter  92 non-null     int64
#  8   apartment_completion_year     92 non-null     int64
#  9   apartment_floor               92 non-null     int64
#  10  apartment_floors_total        92 non-null     float64
#  11  apartment_ceilingheight       92 non-null     float64
#  12  apartment_room                92 non-null     int64
#  13  apartment_ppm                 92 non-null     int64
#  14  apartment_address             92 non-null     object
#  15  apartment_location_lat        92 non-null     float64
#  16  apartment_location_lon        92 non-null     float64
# dtypes: float64(5), int64(7), object(5)
# memory usage: 12.9+ KB

# %%
df
# Out:
#                                                                                              title
# 0                              Академическая 1 9 17.9 Профсоюзная ул., д. 2/22 55.687477,37.572378  \
# 1                                Селигерская 2 10 21.9 пр-д Ильменский, вл. 12 55.859441,37.545155
# 2             Нагатинская D 19 26.0 г. Москва, Нагатинская набережная, уч. 10А 55.682432,37.637749
# 3                 Южнопортовая 4 7 17.6 Г. Москва, ул. Южнопортовая, вл.28-28а 55.705727,37.696445
# 4             Нагатинская D 15 20.2 г. Москва, Нагатинская набережная, уч. 10А 55.682432,37.637749
# 5                 Южнопортовая 4 2 24.8 Г. Москва, ул. Южнопортовая, вл.28-28а 55.705727,37.696445
#
# 65  https://level.ru/api/flat/?limit=8&offset=1304            24.0
# 66  https://level.ru/api/flat/?limit=8&offset=1304            23.5
# 67  https://level.ru/api/flat/?limit=8&offset=1304            21.5
# 68  https://level.ru/api/flat/?limit=8&offset=1304            26.1
# 69  https://level.ru/api/flat/?limit=8&offset=1304            26.1
# 70  https://level.ru/api/flat/?limit=8&offset=1304            23.4
# 71  https://level.ru/api/flat/?limit=8&offset=1304            17.7
# 72  https://level.ru/api/flat/?limit=8&offset=1296            23.4
# 73  https://level.ru/api/flat/?limit=8&offset=1296            22.0
# 74  https://level.ru/api/flat/?limit=8&offset=1296            22.3
# 75  https://level.ru/api/flat/?limit=8&offset=1296            17.9
# 78  https://level.ru/api/flat/?limit=8&offset=1296            22.4
# 79  https://level.ru/api/flat/?limit=8&offset=1296            22.9
# 80  https://level.ru/api/flat/?limit=8&offset=1288            21.3
# 81  https://level.ru/api/flat/?limit=8&offset=1288            21.7
# 82  https://level.ru/api/flat/?limit=8&offset=1288            23.3
# 84  https://level.ru/api/flat/?limit=8&offset=1288            17.3
# 86  https://level.ru/api/flat/?limit=8&offset=1288            17.5
# 87  https://level.ru/api/flat/?limit=8&offset=1288            22.7
# 88  https://level.ru/api/flat/?limit=8&offset=1280            20.7
# 89  https://level.ru/api/flat/?limit=8&offset=1280            20.3
# 90  https://level.ru/api/flat/?limit=8&offset=1280            20.3
# 91  https://level.ru/api/flat/?limit=8&offset=1280            21.5
# 92  https://level.ru/api/flat/?limit=8&offset=1280            22.1
# 93  https://level.ru/api/flat/?limit=8&offset=1280            20.4
# 94  https://level.ru/api/flat/?limit=8&offset=1280            23.7
# 95  https://level.ru/api/flat/?limit=8&offset=1280            24.4
# 96  https://level.ru/api/flat/?limit=8&offset=1272            23.4
# 97  https://level.ru/api/flat/?limit=8&offset=1272            25.7
# 98  https://level.ru/api/flat/?limit=8&offset=1272            21.4
# 99  https://level.ru/api/flat/?limit=8&offset=1272            20.6
#
#     apartment_completion_quarter  apartment_completion_year  apartment_floor
# 0                              1                       2026                9  \
# 1                              2                       2025               10
# 2                              2                       2024               19
# 3                              2                       2026                7
# 4                              2                       2024               15
# 5                              2                       2026                2
# 6                              4                       2022               22
# 7                              2                       2026               15
# 8                              2                       2024                9
# 9                              4                       2022                2
# 10                             2                       2025               11
# 11                             3                       2024                4
# 12                             3                       2025                2
# 13                             2                       2024               19
# 14                             1                       2025                5
# 15                             4                       2022               24
# 16                             2                       2025               22
# 18                             2                       2026                3
# 19                             2                       2024               15
# 20                             1                       2026                8
# 21                             2                       2024               25
# 22                             2                       2025                9
# 23                             4                       2023               27
# 24                             1                       2026               12
# 25                             2                       2024               26
# 27                             3                       2024               10
# 28                             3                       2025                9
# 29                             3                       2025               20
# 30                             1                       2026               10
# 31                             3                       2025                9
# 32                             2                       2026                3
# 33                             1                       2026               14
# 34                             2                       2026                2
# 35                             2                       2024               19
# 36                             3                       2024                2
# 37                             2                       2024                3
# 38                             3                       2024               16
# 39                             1                       2026                9
# 40                             2                       2026                3
# 33         649353                    Профсоюзная ул., д. 2/22
# 34         322232      Г. Москва, ул. Южнопортовая, вл.28-28а
# 35         445462  г. Москва, Нагатинская набережная, уч. 10А
# 36         314446            Волоколамское ш., д. 81, корп. 2
# 37         408425  г. Москва, Нагатинская набережная, уч. 10А
# 38         589090                        Причальный пр., д. 8
# 39         595263                    Профсоюзная ул., д. 2/22
# 40         342201      Г. Москва, ул. Южнопортовая, вл.28-28а
# 41         543736                        Причальный пр., д. 8
# 42         372528      Г. Москва, ул. Южнопортовая, вл.28-28а
# 43         548223               Г. Москва, Озерная ул., вл. 7
# 44         558647                        Причальный пр., д. 8
# 45         375184      Г. Москва, ул. Южнопортовая, вл.28-28а
# 46         392656      Г. Москва, ул. Южнопортовая, вл.28-28а
# 47         325716            Волоколамское ш., д. 81, корп. 2
# 48         556623               Г. Москва, Озерная ул., вл. 7
# 49         362165      Г. Москва, ул. Южнопортовая, вл.28-28а
# 50         392389      Г. Москва, ул. Южнопортовая, вл.28-28а
# 51         611468                        Причальный пр., д. 8
# 52         334167            Волоколамское ш., д. 81, корп. 2
# 53         395381      Г. Москва, ул. Южнопортовая, вл.28-28а
# 54         422788      Г. Москва, ул. Южнопортовая, вл.28-28а
# 55         324884            Волоколамское ш., д. 81, корп. 2
# 56         308198            Волоколамское ш., д. 81, корп. 2
# 57         433853      Г. Москва, ул. Южнопортовая, вл.28-28а
# 58         552691  г. Москва, Нагатинская набережная, уч. 10А
# 59         320814            Волоколамское ш., д. 81, корп. 2
# 61         328525            Волоколамское ш., д. 81, корп. 2
# 62         364339      Г. Москва, ул. Южнопортовая, вл.28-28а
# 64         460058      Г. Москва, ул. Южнопортовая, вл.28-28а
# 65         336828            Волоколамское ш., д. 81, корп. 2
# 66         349085            Волоколамское ш., д. 81, корп. 2
# 67         463043  г. Москва, Нагатинская набережная, уч. 10А
# 68         438803  г. Москва, Нагатинская набережная, уч. 10А
# 69         327659            Волоколамское ш., д. 81, корп. 2
# 70         400197  г. Москва, Нагатинская набережная, уч. 10А
# 71         499622      Г. Москва, ул. Южнопортовая, вл.28-28а
# 72         391613      Г. Москва, ул. Южнопортовая, вл.28-28а
# 73         606718                        Причальный пр., д. 8
# 74         351191      Г. Москва, ул. Южнопортовая, вл.28-28а
# 75         729711                    Профсоюзная ул., д. 2/22
# 78         526917               Г. Москва, Озерная ул., вл. 7
# 79         535222               Г. Москва, Озерная ул., вл. 7
# 80         461861  г. Москва, Нагатинская набережная, уч. 10А
# 81         592362                        Причальный пр., д. 8
# 82         402484  г. Москва, Нагатинская набережная, уч. 10А
# 84         705242                        Причальный пр., д. 8
# 86         432118      Г. Москва, ул. Южнопортовая, вл.28-28а
# 87         519607               Г. Москва, Озерная ул., вл. 7
# 88         452938  г. Москва, Нагатинская набережная, уч. 10А
# 89         441729  г. Москва, Нагатинская набережная, уч. 10А
# 90         452928  г. Москва, Нагатинская набережная, уч. 10А
# 91         328260            Волоколамское ш., д. 81, корп. 2
# 92         738730                        Причальный пр., д. 8
# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"],df["price_sale"], alpha=0.4)
plt.xlabel("apartment_area")
plt.ylabel("price_sale")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, 'price_sale')

# %%
df.describe()
# Out:
#               price    price_sale  apartment_area
# count  9.200000e+01  9.200000e+01       92.000000  \
# mean   1.292520e+07  1.006064e+07       22.086957
# std    3.246438e+06  2.733157e+06        3.125092
# min    8.591616e+06  6.443712e+06       17.300000
# 25%    1.038206e+07  7.823183e+06       20.300000
# 50%    1.220567e+07  9.192486e+06       22.000000
# 75%    1.568166e+07  1.220145e+07       23.700000
# max    2.446763e+07  1.835072e+07       35.200000
#
#        apartment_completion_quarter  apartment_completion_year
# count                     92.000000                  92.000000  \
# mean                       2.445652                2024.565217
# std                        0.843386                   1.294998
# min                        1.000000                2022.000000
# 25%                        2.000000                2024.000000
# 50%                        2.000000                2024.000000
# 75%                        3.000000                2026.000000
# max                        4.000000                2026.000000
#
#        apartment_floor  apartment_floors_total  apartment_ceilingheight
# count        92.000000               92.000000                92.000000  \
# mean         13.684783               29.228261                 2.948261
# std          11.322378               11.790388                 0.101825
# min           2.000000               14.000000                 2.800000
# 25%           4.000000               24.000000                 2.870000
# 50%          12.000000               26.000000                 2.900000
# 75%          20.000000               30.000000                 3.000000
# max          54.000000               69.000000                 3.400000
#
#        apartment_room  apartment_ppm  apartment_location_lat
# count            92.0      92.000000               92.000000  \
# mean              0.0  456713.978261               55.729697
# std               0.0  109926.916560                0.057842
# min               0.0  305747.000000               55.682432
# 25%               0.0  366328.750000               55.687477
# 50%               0.0  437590.500000               55.705727
# 75%               0.0  537684.500000               55.760180
# max               0.0  738730.000000               55.859441
#
#        apartment_location_lon
# count               92.000000
# mean                37.574808
# std                  0.103905
# min                 37.411886
# 25%                 37.471704
# 50%                 37.572378
# 75%                 37.696445
# max                 37.696445

# %%
#import seaborn as sns
##penguins = sns.load_dataset(df)
#sns.pairplot(df)

# %%
#plt.show()

# %%
# importing packages
import seaborn
import pandas 
import matplotlib.pyplot as plt

# %%
# load the csv
#data = pandas.read_csv("nba.csv")
 
# pairplot
seaborn.pairplot(df)
#plt.show()

# %%
seaborn.pairplot(df.drop(['price', 'apartment_ppm','title', 'datetime_create', 'category', 'source_url', 'apartment_address','apartment_location_lat','apartment_location_lon'], axis=1 ))

# 'price_sale',

# %%
#Хотим спрогнозировать стоимость квартиры?
2.463307e+07

# %%
model = LinearRegression()

# %%
df_train = df.drop(['price', 'apartment_ppm', 'price_sale', 'title', 'datetime_create', 'category', 'source_url', 'apartment_address', 'apartment_location_lat', 'apartment_location_lon'], axis=1 )
df_y = df[['price_sale']].copy()

# %%
df_train

# %%
df_y

# %%
#np.any(np.isnan(df_train))
#df_train = df_train.reset_index()
#df_train
#df_y = df_y.reset_index()
#df_y

# %%
model.fit(df_train, df_y)

# %% [markdown]
# $ x_1 * k_1 + x_2 * k_2 + b = y $

# %%
model.coef_

# %%
# вспоминить что это?
model.intercept_

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"],df["price_sale"], alpha=0.4)
plt.xlabel("price_sale")
plt.ylabel("apartment_area")
#plt.ylim(10,120)

#plt.plot(df_train, model.predict(df_train))
#plt.plot(df_train['apartment_area'], model.predict(df_train))
plt.scatter(df_train['apartment_area'], model.predict(df_train), alpha=0.4)

# %%
# R**2
model.score(df_train, df_y)

# %% [markdown]
# $ R^2 = 1 - sum((y - y^)^2) / sum((y - y_)^2) $

# %%
df

# %%
#df_t = pd.DataFrame([[66.2,4,2026,30,32,3.00,2,55.760180,37.517482]], columns=["apartment_area","apartment_completion_quarter","apartment_completion_year","apartment_floor","apartment_floors_total","apartment_ceilingheight","apartment_room","apartment_location_lat","apartment_location_lon"])
# 69200322 и с скидкой 48440225
#df_t = pd.DataFrame([[66.2,4,2023,13,32,3.00,2,55.760180,37.517482]], columns=["apartment_area","apartment_completion_quarter","apartment_completion_year","apartment_floor","apartment_floors_total","apartment_ceilingheight","apartment_room","apartment_location_lat","apartment_location_lon"])
df_t = pd.DataFrame([[66.2,4,2023,13,32,3.00,2]], columns=["apartment_area","apartment_completion_quarter","apartment_completion_year","apartment_floor","apartment_floors_total","apartment_ceilingheight","apartment_room"])
model.predict(df_t)

# %%
model.predict([[66.2,4,2023,13,32,3.00,2,55.760180,37.517482]])

# %%
model.predict(df_train)

# %%
# не то поставил
#!pip install scrapy

# %%
#root@malvina8:/home/jupyter-amtsu# python3 -m pip install xgboost
#Requirement already satisfied: xgboost in /usr/local/lib/python3.8/dist-packages (1.7.3)
#Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.10.0)
#Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.24.2)

# %%
def f():
    return [1,2,3,4]

print(type(f()))

k = f()
x,y,u,i = f()
print(y)
print(i)
print(k)

# %%
#!pip install numpy

# %%
#!pip install scipy

# %%
#!pip install xgboost --no-cache-dir

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_train, df_y, test_size=0.2, random_state=546)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(df_train, df_y, test_size=0.2, random_state=546)
#
# NameError: name 'df_train' is not defined

# %%
import xgboost as xgb
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
#xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
#                max_depth = 5, alpha = 10, n_estimators = 10)
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror')
#xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
#                max_depth = 5, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(X_train,y_train)

# %%
preds = xg_reg.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))

# %%
# средне квадратичное отклонение
-3 * RMSE ~ 3 * RMSE = 0,97

# %%
xg_reg.predict(df_t)

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"],df["price_sale"], alpha=0.4)
plt.xlabel("price_sale")
plt.ylabel("apartment_area")
#plt.ylim(10,120)

#plt.plot(df_train, model.predict(df_train))
#plt.plot(df_train['apartment_area'], model.predict(df_train))

plt.scatter(df_train['apartment_area'], model.predict(df_train), alpha=0.4,  color="green")
plt.scatter(df_train['apartment_area'], xg_reg.predict(df_train), alpha=0.4,  color="pink")

plt.scatter(df_t['apartment_area'], model.predict(df_t), alpha=0.4, color="black")
plt.scatter(df_t['apartment_area'], xg_reg.predict(df_t), alpha=0.4, color="red")

#  и с скидкой 
plt.scatter(df_t['apartment_area'], 69200322, alpha=0.4)
plt.scatter(df_t['apartment_area'], 48440225, alpha=0.4)

#plt.scatter(df_train['apartment_area'], model.predict(df_train), alpha=0.4)

# %%
#df_train, df_y

data_dmatrix = xgb.DMatrix(data=df_train,label=df_y)
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 15, 'alpha': 30}

cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=13,
                    num_boost_round=150,early_stopping_rounds=110,metrics="rmse", as_pandas=True, seed=123)

# %%
cv_results.head()

# %%
print((cv_results["test-rmse-mean"]).tail(1))

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"],df["price_sale"], alpha=0.4)
plt.xlabel("apartment_area")
plt.ylabel("price_sale")
plt.xlim(15, 50)
plt.ylim(2000000, 20000000)


#plt.plot(df_train, model.predict(df_train))
#plt.plot(df_train['apartment_area'], model.predict(df_train))

plt.scatter(df_train['apartment_area'], model.predict(df_train), alpha=0.4)
plt.scatter(df_train['apartment_area'], xg_reg.predict(df_train), alpha=0.4, )

plt.scatter(df_t['apartment_area'], model.predict(df_t), alpha=0.4, color="black")
plt.scatter(df_t['apartment_area'], xg_reg.predict(df_t), alpha=0.4, color="red")

#  и с скидкой 
plt.scatter(df_t['apartment_area'], 69200322, alpha=0.4)
plt.scatter(df_t['apartment_area'], 48440225, alpha=0.4)

#plt.scatter(df_train['apartment_area'], model.predict(df_train), alpha=0.4)

# %%
#df_train = df.drop(['price', 'apartment_ppm', 'price_sale', 'title', 'datetime_create', 'category', 'source_url', 'apartment_address'], axis=1 )
#df_y = df[['price_sale']].copy()

#xg_reg.fit(df,df_y)

# %%
xg_reg.score(X_train,y_train)

# %%
# визуализировать дерево решеней для XGB

# %% [markdown]
# # Добавил дни экспозиции и дополнит ельные паремтры

# %%
cursor.execute("""
WITH sales_numbered AS (
SELECT 
    id, 
    title,
    price_sale,
    --LEAD(price_sale,1,0) OVER (PARTITION BY title, url, apartment_floor, apartment_room, apartment_area ORDER BY  title, id desc ) AS prev_price_sale,  
    apartment_area,
    
    price,
    datetime_create,
    category,
    url,
    source_url,
--    apartment_completion_quarter,
    apartment_completion_year,
    apartment_floor,
    apartment_floors_total,
--    apartment_ceilingheight,
    apartment_room,
    apartment_ppm,
    apartment_address,
    apartment_location_lat,
    apartment_location_lon,
    
    "2022-12-17" as date_start_import,
    MIN(datetime_create) OVER (PARTITION BY title, url ) as datetime_create_min,
    MAX(datetime_create) OVER (PARTITION BY title, url ) as datetime_create_max,
    julianday(date(MAX(datetime_create) OVER (PARTITION BY title, url ))) - julianday(date(MIN(datetime_create) OVER (PARTITION BY title, url ))) as days_of_exposure,
    
    MIN(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 6 FOLLOWING) as d7_min,
    AVG(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 6 FOLLOWING) as d7_avg,
    MAX(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 6 FOLLOWING) as d7_max,
    
    MIN(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 29 FOLLOWING) as d30_min,
    AVG(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 29 FOLLOWING) as d30_avg,
    MAX(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 29 FOLLOWING) as d30_max,

    MIN(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 89 FOLLOWING) as d90_min,
    AVG(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 89 FOLLOWING) as d90_avg,
    MAX(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 89 FOLLOWING) as d90_max,

    MIN(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 364 FOLLOWING) as d365_min,
    AVG(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 364 FOLLOWING) as d365_avg,
    MAX(price_sale) OVER (PARTITION BY title, url ORDER BY title, id desc ROWS BETWEEN CURRENT ROW AND 364 FOLLOWING) as d365_max,
    
    MIN(price_sale) OVER (PARTITION BY title, url ) as all_min,
    AVG(price_sale) OVER (PARTITION BY title, url ) as all_avg,
    MAX(price_sale) OVER (PARTITION BY title, url ) as all_max,

    price_sale - LEAD(price_sale,1,0) OVER (PARTITION BY title, url  ORDER BY title, id desc ) AS diff,
    ROW_NUMBER() OVER(PARTITION BY title, url ORDER BY id desc) AS row_number
FROM products_history
where datetime_create >= "2022-01-17"
    and (
        url like "%level.ru%" 
        or 
        url like "%fr.mos.ru%"
    )
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id desc
LIMIT 3000000     
)
SELECT 

    id, 
    title,
    price_sale,
    apartment_area,
    
    price,
    datetime_create,
    category,
    
    
    url,
    
    
    source_url,
--    apartment_completion_quarter,
    apartment_completion_year,
    apartment_floor,
    apartment_floors_total,
--    apartment_ceilingheight,
    apartment_room,
    apartment_ppm,
    apartment_address,
    apartment_location_lat,
    apartment_location_lon,
    
    
    date_start_import,
    datetime_create_min,
    datetime_create_max,
    --date(datetime_create_max),
    --datetime(datetime_create_max),
    --julianday(date(datetime_create_max)) - julianday(date(datetime_create_min)) as days_of_exposure,
    days_of_exposure,
    CASE
        WHEN days_of_exposure < 7 
            THEN 1
        ELSE 0
    END AS d7_sale,
    CASE
        WHEN days_of_exposure >= 7 and days_of_exposure < 40 
--        WHEN days_of_exposure < 40 
            THEN 1
        ELSE 0
    END AS d30_sale,
    CASE
        WHEN days_of_exposure >= 40 and days_of_exposure < 110 
--        WHEN days_of_exposure < 110 
            THEN 1
        ELSE 0
    END AS d90_sale,
    CASE
        WHEN days_of_exposure >= 110 and days_of_exposure < 400 
--        WHEN  days_of_exposure < 400 
            THEN 1
        ELSE 0
    END AS d365_sale,

    d7_min,
    d7_avg,
    d7_max,

    d30_min,
    d30_avg,
    d30_max,

    d90_min,
    d90_avg,
    d90_max,

    d365_min,
    d365_avg,
    d365_max,

    all_min,
    all_avg,
    all_max,
    --price_sale / apartment_area,

    row_number
FROM sales_numbered
WHERE row_number = 1
--Order by days_of_exposure desc;
Order by days_of_exposure asc;

""")

# %%
#cursor.fetchall()

# %%
df = pd.DataFrame(cursor.fetchall(), columns=[
        
    "id", 
    "title",
    "price_sale",
    "apartment_area",
    
    "price",
    "datetime_create",
    "category",
    "url",
    "source_url",
#    "apartment_completion_quarter",
    "apartment_completion_year",
    "apartment_floor",
    "apartment_floors_total",
#    "apartment_ceilingheight",
    "apartment_room",
    "apartment_ppm",
    "apartment_address",
    "apartment_location_lat",
    "apartment_location_lon",
    
    "date_start_import",
    "datetime_create_min",
    "datetime_create_max",
    "days_of_exposure",
    "d7_sale",
    "d30_sale",
    "d90_sale",
    "d365_sale",

    "d7_min",
    "d7_avg",
    "d7_max",

    "d30_min",
    "d30_avg",
    "d30_max",

    "d90_min",
    "d90_avg",
    "d90_max",

    "d365_min",
    "d365_avg",
    "d365_max",

    "all_min",
    "all_avg",
    "all_max",

    "row_number"
])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3014 entries, 0 to 3013
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         3014 non-null   int64
#  1   title                      3014 non-null   object
#  2   price_sale                 3014 non-null   int64
#  3   apartment_area             2999 non-null   float64
#  4   price                      3014 non-null   int64
#  5   datetime_create            3014 non-null   object
#  6   category                   3014 non-null   object
#  7   url                        3014 non-null   object
#  8   source_url                 2986 non-null   object
#  9   apartment_completion_year  1926 non-null   float64
#  10  apartment_floor            1926 non-null   float64
#  11  apartment_floors_total     1926 non-null   float64
#  12  apartment_room             1926 non-null   float64
#  13  apartment_ppm              1926 non-null   float64
#  14  apartment_address          1926 non-null   object
#  15  apartment_location_lat     1926 non-null   float64
#  16  apartment_location_lon     1926 non-null   float64
#  17  date_start_import          3014 non-null   object
#  18  datetime_create_min        3014 non-null   object
#  19  datetime_create_max        3014 non-null   object
#  20  days_of_exposure           3014 non-null   float64
#  21  d7_sale                    3014 non-null   int64
#  22  d30_sale                   3014 non-null   int64
#  23  d90_sale                   3014 non-null   int64
#  24  d365_sale                  3014 non-null   int64
#  25  d7_min                     3014 non-null   int64
#  26  d7_avg                     3014 non-null   float64
#  27  d7_max                     3014 non-null   int64
#  28  d30_min                    3014 non-null   int64
#  29  d30_avg                    3014 non-null   float64
#  30  d30_max                    3014 non-null   int64
#  31  d90_min                    3014 non-null   int64
#  32  d90_avg                    3014 non-null   float64
#  33  d90_max                    3014 non-null   int64
#  34  d365_min                   3014 non-null   int64
#  35  d365_avg                   3014 non-null   float64
#  36  d365_max                   3014 non-null   int64
#  37  all_min                    3014 non-null   int64
#  38  all_avg                    3014 non-null   float64
#  39  all_max                    3014 non-null   int64
#  40  row_number                 3014 non-null   int64
# dtypes: float64(14), int64(18), object(9)
# memory usage: 965.5+ KB

# %%
#3014

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1926 entries, 0 to 3013
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1926 non-null   int64
#  1   title                      1926 non-null   object
#  2   price_sale                 1926 non-null   int64
#  3   apartment_area             1926 non-null   float64
#  4   price                      1926 non-null   int64
#  5   datetime_create            1926 non-null   object
#  6   category                   1926 non-null   object
#  7   url                        1926 non-null   object
#  8   source_url                 1926 non-null   object
#  9   apartment_completion_year  1926 non-null   float64
#  10  apartment_floor            1926 non-null   float64
#  11  apartment_floors_total     1926 non-null   float64
#  12  apartment_room             1926 non-null   float64
#  13  apartment_ppm              1926 non-null   float64
#  14  apartment_address          1926 non-null   object
#  15  apartment_location_lat     1926 non-null   float64
#  16  apartment_location_lon     1926 non-null   float64
#  17  date_start_import          1926 non-null   object
#  18  datetime_create_min        1926 non-null   object
#  19  datetime_create_max        1926 non-null   object
#  20  days_of_exposure           1926 non-null   float64
#  21  d7_sale                    1926 non-null   int64
#  22  d30_sale                   1926 non-null   int64
#  23  d90_sale                   1926 non-null   int64
#  24  d365_sale                  1926 non-null   int64
#  25  d7_min                     1926 non-null   int64
#  26  d7_avg                     1926 non-null   float64
#  27  d7_max                     1926 non-null   int64
#  28  d30_min                    1926 non-null   int64
#  29  d30_avg                    1926 non-null   float64
#  30  d30_max                    1926 non-null   int64
#  31  d90_min                    1926 non-null   int64
#  32  d90_avg                    1926 non-null   float64
#  33  d90_max                    1926 non-null   int64
#  34  d365_min                   1926 non-null   int64
#  35  d365_avg                   1926 non-null   float64
#  36  d365_max                   1926 non-null   int64
#  37  all_min                    1926 non-null   int64
#  38  all_avg                    1926 non-null   float64
#  39  all_max                    1926 non-null   int64
#  40  row_number                 1926 non-null   int64
# dtypes: float64(14), int64(18), object(9)
# memory usage: 632.0+ KB

# %%
#1748
#1926

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"],df["price_sale"], alpha=0.4)
plt.xlabel("apartment_area")
plt.ylabel("price_sale")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, 'price_sale')

# %%
df_train = df.drop(['price', 'apartment_ppm', 'price_sale', 'title', 'datetime_create', 'category', 'url', 'source_url', 'apartment_address', 'apartment_location_lat', 'apartment_location_lon',       
    "id",

#    "apartment_completion_quarter",
    
    "date_start_import",
    "datetime_create_min",
    "datetime_create_max",
                    
    "days_of_exposure",          
                    
    "d7_min",
    "d7_avg",
    "d7_max",

    "d30_min",
    "d30_avg",
    "d30_max",

    "d90_min",
    "d90_avg",
    "d90_max",

    "d365_min",
    "d365_avg",
    "d365_max",

    "all_min",
    "all_avg",
    "all_max",

    "row_number"
                   
                   ], axis=1 )
df_y = df[['price_sale']].copy()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_train, df_y, test_size=0.2, random_state=546)

# %%
import xgboost as xgb
import numpy as np
from sklearn.metrics import mean_squared_error

#xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
#                max_depth = 5, alpha = 10, n_estimators = 10)
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror')
#xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
#                max_depth = 5, alpha = 10, n_estimators = 10)

xg_reg.fit(X_train,y_train)

preds = xg_reg.predict(X_test)

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"],df["price_sale"], alpha=0.4)
plt.xlabel("price_sale")
plt.ylabel("apartment_area")
#plt.ylim(10,120)

#plt.plot(df_train, model.predict(df_train))
#plt.plot(df_train['apartment_area'], model.predict(df_train))
plt.scatter(X_test['apartment_area'], preds, alpha=0.4)

# %%
filename = 'calculate_price_apartment/model_xgb.sav'
xg_reg.save_model(filename)

# %%
pwd
# Out:
# '/home/jupyter-amtsu/github/team22/library/theory'

# %%
import pickle
filename = 'calculate_price_apartment/model_xgb.sav'
pickle.dump(xg_reg, open(filename, 'wb'))

# %%
df_t = pd.DataFrame([[30,2023,13,32,1,0,1,0,0]], columns=[
    "apartment_area",
#    "apartment_completion_quarter",
    "apartment_completion_year",
    "apartment_floor",
    "apartment_floors_total",
#    "apartment_ceilingheight",
    "apartment_room",

    "d7_sale",
    "d30_sale", 
    "d90_sale",
    "d365_sale"
])
 

xg_reg.predict(df_t)
# Out:
# array([17523176.], dtype=float32)

# %%
model = LinearRegression()


model.fit(df_train, df_y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[ 1.57714966e+06,  2.47039567e+06, -3.19111360e+03,
#         -2.67625266e+05, -2.33128184e+07, -7.29685226e+05,
#         -2.04680915e+06,  1.15976825e+06,  1.61672613e+06]])

# %%
model.intercept_
# Out:
# array([-5.00654994e+09])

# %%
import pickle

# %%
filename = 'calculate_price_apartment/model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"],df["price_sale"], alpha=0.4)
plt.xlabel("price_sale")
plt.ylabel("apartment_area")
#plt.ylim(10,120)

#plt.plot(df_train, model.predict(df_train))
#plt.plot(df_train['apartment_area'], model.predict(df_train))
plt.scatter(df_train['apartment_area'], model.predict(df_train), alpha=0.4)

# %%
#df_t = pd.DataFrame([[30.5,4,2023,13,32,3.00,1]], columns=[
#    "apartment_area",
#    "apartment_completion_quarter",
#    "apartment_completion_year",
#    "apartment_floor",
#    "apartment_floors_total",
#    "apartment_ceilingheight",
#    "apartment_room"])

#price', 'apartment_ppm', 'price_sale', 'title', 'datetime_create', 'category', 'source_url', 
#'apartment_address', 'apartment_location_lat', 'apartment_location_lon',       
#    "date_start_import",
#    "datetime_create_min",
#    "datetime_create_max"

#", 
#df_t = pd.DataFrame([[30.5,4,2023,13,32,3.00,1,0,1,0,0]], columns=[
#df_t = pd.DataFrame([[30.5,2023,3,32,3.00,1,0,1,0,0]], columns=[
df_t = pd.DataFrame([[30.5,2023,3,32,1,0,1,0,0]], columns=[


    "apartment_area",
#    "apartment_completion_quarter",
    "apartment_completion_year",
    "apartment_floor",
    "apartment_floors_total",
#    "apartment_ceilingheight",
    "apartment_room",


    "d7_sale",
    "d30_sale", 
    "d90_sale",
    "d365_sale"
])
 

model.predict(df_t)
# Out:
# array([[5230366.26808167]])

# %%
#df_t = pd.DataFrame([[30.5,2023,13,32,3.00,1,0,1,0,0]], columns=[
df_t = pd.DataFrame([[30.5,2023,13,32,1,0,1,0,0]], columns=[


    "apartment_area",
#    "apartment_completion_quarter",
    "apartment_completion_year",
    "apartment_floor",
    "apartment_floors_total",
#    "apartment_ceilingheight",
    "apartment_room",


    "d7_sale",
    "d30_sale", 
    "d90_sale",
    "d365_sale"
])
 

model.predict(df_t)
# Out:
# array([[5198455.13208485]])

# %%
# высиялюю изменние средней площади квадратного метра по дням / неделям

# %%
cursor.execute("""
SELECT 
    id, 
    price_sale,
    CAST(apartment_area as int),
    CAST(price_sale / apartment_area as decimal(15,2)),
    date(datetime_create) as date
    
FROM products_history
where datetime_create >= "2022-01-17"
    and url like "%level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id desc
LIMIT 4
""")

#cursor.fetchall()


df = pd.DataFrame(cursor.fetchall(), columns=[
    "id", 
    "price_sale",
    "apartment_area",
    "price per metr",
    "date"
])

# %%
df

# %%
df.describe()

# %%
import re

# %%
cursor.execute("""
SELECT 
    id, 
    title,
    price_sale,
    apartment_area,
    CAST(apartment_area as decimal) as apartment_area,
    CAST(price_sale as decimal(15,2)) / CAST(apartment_area as decimal(15,2)),
    --*,
    date(datetime_create) as date
    
FROM products_history
where 
    datetime_create <= "2023-02-10"
    and url like "%level.ru%"
--    and apartment_area = ""
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id asc
LIMIT 1000000
""")

for i in cursor.fetchall():
    title = i[1]
    iid = i[0]
    aa = i[3]
    datee = i[6]
    result = re.search(r'\d\d\d?\.\d', title)
    mm = 0
    if result:
        mm = result.group(0)
#    if not aa:
#        print(aa , '!=', mm, datee)
#    elif float(aa) != float(mm):  
#        print(iid, mm, title)
        
    #update
#    print( f"""UPDATE products_history
#SET apartment_area = '{mm}'
#WHERE id = '{iid}';
#""")
    print(iid)
    cursor.execute(f"""UPDATE products_history
SET apartment_area = '{mm}'
WHERE id = '{iid}';
""")

# %%
connection.commit()

# %%
#5008519
cursor.execute("""
SELECT 
    id, 
    title,
    price_sale,
    apartment_area
    
FROM products_history
where 
    id = 4726131
""")

cursor.fetchall()

# %%
cursor.execute("""
WITH sales_numbered AS (
SELECT 
    id, 
    price_sale,
    CAST(apartment_area as decimal) as apartment_area,
    CAST(price_sale / apartment_area as decimal(15,2)),
    date(datetime_create) as date
    
FROM products_history
where 
    --datetime_create >= "2022-01-17"
     url like "%level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id asc
LIMIT 1431
)
SELECT 
    cast(sum(price_sale) as int),
    cast(sum(apartment_area) as int),
    cast(avg(price_sale / apartment_area) as int),
    cast(sum(price_sale) / sum(apartment_area) as int),
    date
    
FROM sales_numbered

group by date
ORDER BY date
LIMIT 331  
""")

#cursor.fetchall()


df = pd.DataFrame(cursor.fetchall(), columns=[
    "sum price_sale",
    "sum apartment_area",
    "avg price per metr",
    "avg sum price per sum metr",
    "date"
])

# %%
df

# %%
cursor.execute("""
WITH sales_numbered AS (
SELECT 
    id, 
    price_sale,
    CAST(apartment_area as decimal) as apartment_area,
    CAST(price_sale / apartment_area as decimal(15,2)),
    date(datetime_create) as date
    
FROM products_history
where 
--datetime_create >= "2022-01-17"
    --and 
    url like "%level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id desc
LIMIT 1431111
)
SELECT 
    cast(sum(price_sale) as int),
    cast(sum(apartment_area) as int),
    cast(avg(price_sale / apartment_area) as int),
    cast(sum(price_sale) / sum(apartment_area) as int),
    avg(apartment_area),
    avg(price_sale),
    date
    
FROM sales_numbered

group by date
ORDER BY date
LIMIT 331  
""")

#cursor.fetchall()


df = pd.DataFrame(cursor.fetchall(), columns=[
    "sum price_sale",
    "sum apartment_area",
    "avg price per metr",
    "avg sum price per sum metr",
    "avg apartment_area",
    "avg price",
    "date"
])

# %%
df
# Out:
#      sum price_sale  sum apartment_area  avg price per metr
# 0       32334941046             68096.0            406989.0  \
# 1       30696512003             67179.0            397938.0
# 2       30559637400             66794.0            398361.0
# 3       30209952834             66136.0            397052.0
# 4       30307550429             66438.0            397075.0
# 5       30343321095             66328.0            398268.0
# 6       30034772231             66288.0            395448.0
# 7       29991524065             66147.0            395574.0
# 8       29863034824             65691.0            396268.0
# 9       29837910937             65549.0            396862.0
# 10      30136225876             66511.0            395505.0
# 11      29768570184             65633.0            395154.0
# 12      31160291393             68388.0            400211.0
# 13      31781263429             69010.0            402714.0
# 14      31726087324             68856.0            402831.0
# 15      31486613877             68149.0            403513.0
# 16      31548308252             68145.0            404388.0
# 17      31637094155             68269.0            405164.0
# 18      31436265383             67640.0            405775.0
# 19      31457721927             67532.0            406705.0
# 20      31289509667             67102.0            406767.0
# 21      31135844571             66730.0            406750.0
# 22      31374993489             67539.0            405192.0
# 23      31417976675             67560.0            405720.0
# 24      31412807680             67436.0            406931.0
# 25      31272910517             67172.0            406216.0
# 26      31298558618             66997.0            407593.0
# 27      31314394420             67021.0            407768.0
# 28      31314394420             67021.0            407768.0
# 29      31314394420             67021.0            407768.0
# 30      31314394420             67021.0            407768.0
# 31      31314394420             67021.0            407768.0
# 32      31314394420             67021.0            407768.0
# 33      31070929123             66386.0            407908.0
# 34      31060292331             66363.0            407856.0
# 35      30965120163             66151.0            407604.0
# 36      30849204746             65835.0            407882.0
# 37      29275035359             65787.0            401011.0
# 38      30841981864             65609.0            408595.0
# 39      30889666759             65627.0            409211.0
# 40      30749709083             65174.0            409844.0
# 41      30692156169             65956.0            407331.0
# 42      25287836453             52539.0            404574.0
# 43      27846557662             61330.0            401162.0
# 44      30476705835             64918.0            407619.0
# 45      30734049440             65517.0            407949.0
# 46      31669129135             68489.0            402260.0
# 47      31541442853             68318.0            401595.0
# 48      32135259204             69480.0            404103.0
# 49      31925978758             68952.0            404201.0
# 50      31717104729             68592.0            402452.0
# 51      31934953760             69000.0            403331.0
# 52      31821867788             68697.0            403634.0
# 53      31646596871             68093.0            404562.0
# 54      31925608021             68637.0            406082.0
# 55      32008096670             68821.0            406159.0
# 56      31761931155             68241.0            405944.0
# 57      31546022966             67629.0            406252.0
# 58      31393136031             67119.0            406964.0
# 59      34620789696             68792.0            421462.0
# 60      30682269516             66801.0            405824.0
# 61      30788227815             67047.0            405978.0
# 62      30605491638             66541.0            406253.0
# 63      30995279243             67449.0            406709.0
# 64      30888239214             67110.0            407209.0
# 65      30894881891             66277.0            412947.0
# 66      30719068777             65834.0            413242.0
# 67      30526321477                 NaN                 NaN
# 68      30599870798             65084.0            415793.0
# 69      30591430658             65084.0            415699.0
# 70      30380125650             64536.0            415790.0
# 113                    475429.0           58.101012  2.762291e+07  2023-04-01
# 114                    475706.0           58.121351  2.764871e+07  2023-04-02
# 115                    475595.0           58.224883  2.769152e+07  2023-04-03
# 116                    476460.0           58.091297  2.767818e+07  2023-04-04
# 117                    476649.0           58.121174  2.770340e+07  2023-04-05
# 118                    478827.0           58.284019  2.790800e+07  2023-04-06
# 119                    472279.0           58.001466  2.739290e+07  2023-04-07
# 120                    470419.0           57.981324  2.727552e+07  2023-04-08
# 121                    471135.0           57.913452  2.728510e+07  2023-04-09
# 122                    471863.0           57.985575  2.736125e+07  2023-04-10
# 123                    471758.0           58.047587  2.738443e+07  2023-04-11
# 124                    470569.0           58.555712  2.755453e+07  2023-04-12
# 125                    472140.0           58.736113  2.773168e+07  2023-04-13
# 126                    463098.0           60.838498  2.817424e+07  2023-04-14
# 127                    472474.0           58.744243  2.775517e+07  2023-04-15
# 128                    474346.0           58.716373  2.785190e+07  2023-04-16
# 129                    474148.0           58.749647  2.785608e+07  2023-04-17
# 130                    466983.0           58.888000  2.749974e+07  2023-04-18
# 131                    460103.0           58.560776  2.694404e+07  2023-04-19
# 132                    461484.0           58.514172  2.700336e+07  2023-04-20

# %%
30307550429 / 66438.0
# Out:
# 456177.9467924983

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["date"],df["sum price_sale"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, '2')

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["date"],df["sum apartment_area"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, '2')

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["date"],df["avg price per metr"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, '2')

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["date"],df["avg sum price per sum metr"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, '2')

# %%
#avg apartment_area
plt.figure(figsize=(12,6))
plt.scatter(df["date"],df["avg apartment_area"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, '2')

# %%
#avg price

#avg apartment_area
plt.figure(figsize=(12,6))
plt.scatter(df["date"],df["avg price"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, '2')

# %%
#вязть распределенеи стоимости по дню
#выбрать все прдлжения за день, рассчиать стоимость квадратного метра и вывести


cursor.execute("""
SELECT 
    id, 
    price_sale,
    CAST(apartment_area as decimal) as apartment_area,
    CAST(price_sale / apartment_area as decimal(15,2)),
    date(datetime_create) as date
    
FROM products_history
where 
    ((datetime_create >= "2023-03-18"
    and 
    datetime_create < "2023-03-19")
    or
    (datetime_create >= "2022-12-07"
    and 
    datetime_create < "2022-12-08"))
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id desc
limit 2
""")

df = pd.DataFrame(cursor.fetchall(), columns=[
    "id",
    "price_sale",
    "apartment_area",
    "avg",
    "date"
])

plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"], df["date"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, '2')

# %%
#вязть распределенеи стоимости по дню
#выбрать все прдлжения за день, рассчиать стоимость квадратного метра и вывести


cursor.execute("""
SELECT 
    id, 
    price_sale,
    CAST(apartment_area as decimal) as apartment_area,
    CAST(price_sale / apartment_area as decimal(15,2)),
    date(datetime_create) as date
    
FROM products_history
where 
    ((datetime_create >= "2023-03-18"
    and 
    datetime_create < "2023-03-19")
    or
    (datetime_create >= "2022-12-07"
    and 
    datetime_create < "2022-12-08"))
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id desc
limit 20000
""")

df = pd.DataFrame(cursor.fetchall(), columns=[
    "id",
    "price_sale",
    "apartment_area",
    "avg",
    "date"
])

plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"], df["date"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)
# Out:
# Text(0, 0.5, '2')

# %%
#вязть распределенеи стоимости по дню
#выбрать все прдлжения за день, рассчиать стоимость квадратного метра и вывести


cursor.execute("""
SELECT 
    id, 
    price_sale,
    CAST(apartment_area as decimal) as apartment_area,
    CAST(price_sale / apartment_area as decimal(15,2)),
    CAST(apartment_area as int) as apartment_area,
    
    CAST((price_sale / apartment_area)/20000 as decimal(15,2)),
    
    date(datetime_create) as date
    
FROM products_history
where 
    (
    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
--    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id desc
limit 20000
""")

df = pd.DataFrame(cursor.fetchall(), columns=[
    "id",
    "price_sale",
    "apartment_area",
    "avg",
    "w",
    "e",
    "date"
])

plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"], df["date"], alpha=0.4)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"], df["e"], alpha=0.05)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)

# %%
#вязть распределенеи стоимости по дню
#выбрать все прдлжения за день, рассчиать стоимость квадратного метра и вывести


cursor.execute("""
SELECT 
    id, 
    price_sale,
    CAST(apartment_area as decimal) as apartment_area,
    CAST(price_sale / apartment_area as decimal(15,2)),
    CAST(apartment_area as int) as apartment_area,
    
    CAST((price_sale / apartment_area)/20000 as decimal(15,2)),
    
    date(datetime_create) as date
    
FROM products_history
where 
    (
--    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
ORDER BY id desc
limit 20000
""")

df = pd.DataFrame(cursor.fetchall(), columns=[
    "id",
    "price_sale",
    "apartment_area",
    "avg",
    "w",
    "e",
    "date"
])

plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"], df["date"], alpha=0.2)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"], df["e"], alpha=0.05)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)

# %%
#вязть распределенеи стоимости по дню
#выбрать все прдлжения за день, рассчиать стоимость квадратного метра и вывести


cursor.execute("""
SELECT 
 
    CAST((price_sale / apartment_area)/100000 as int),
    count(1),
    date(datetime_create) as date
    
FROM products_history
where 
    (
--    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
group by CAST((price_sale / apartment_area)/100000 as int)
ORDER BY id desc
limit 20000
""")

df = pd.DataFrame(cursor.fetchall(), columns=[
    "apartment_area",
    "count",
    "date"
])


df

# %%
plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"], df["count"], alpha=0.2)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)

# %%
#вязть распределенеи стоимости по дню
#выбрать все прдлжения за день, рассчиать стоимость квадратного метра и вывести


cursor.execute("""
SELECT 
 
    CAST((price_sale / apartment_area)/100000 as int),
    count(1),
    date(datetime_create) as date
    
FROM products_history
where 
    (
    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
--    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
group by CAST((price_sale / apartment_area)/100000 as int)
ORDER BY id desc
limit 20000
""")

df = pd.DataFrame(cursor.fetchall(), columns=[
    "apartment_area",
    "count",
    "date"
])

plt.figure(figsize=(12,6))
plt.scatter(df["apartment_area"], df["count"], alpha=0.2)
plt.xlabel("1")
plt.ylabel("2")
#plt.ylim(10,120)

# %%
cursor.execute("""
SELECT 
 title,
 price_sale,
 
 apartment_area,
 price_sale / apartment_area,
    CAST((price_sale / apartment_area)/100000 as int),

    date(datetime_create) as date
    
FROM products_history
where 
    (
    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
--    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
    and CAST((price_sale / apartment_area)/100000 as int)<= 2

ORDER BY id desc
limit 2000000
""")

cursor.fetchall()

# %%
cursor.execute("""
SELECT 
 title,
    CAST((price_sale / apartment_area)/100000 as int),

    date(datetime_create) as date
    
FROM products_history
where 
    (
    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
--    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
    and CAST((price_sale / apartment_area)/100000 as int)<= 1

ORDER BY id desc
limit 2000000
""")

cursor.fetchall()

# %%
cursor.execute("""
SELECT 
 title,
    CAST((price_sale / apartment_area)/100000 as int),

    date(datetime_create) as date
    
FROM products_history
where 
    (
--    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
    and CAST((price_sale / apartment_area)/100000 as int)<= 2

ORDER BY id desc
limit 2000000
""")

cursor.fetchall()

# %%
cursor.execute("""
SELECT 
 title,
 price_sale,
 
 apartment_area,
 price_sale / apartment_area,
    CAST((price_sale / apartment_area)/100000 as int),

    date(datetime_create) as date
    
FROM products_history
where 
    (
    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
--    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
    and CAST((price_sale / apartment_area)/100000 as int)>= 20

ORDER BY id desc
limit 2000000
""")

cursor.fetchall()

# %%
cursor.execute("""
SELECT 
 title,
 price_sale,
 
 apartment_area,
 price_sale / apartment_area,
    CAST((price_sale / apartment_area)/100000 as int),

    date(datetime_create) as date
    
FROM products_history
where 
    (
--    (datetime_create >= "2023-03-18"    and  datetime_create < "2023-03-19")
--    or
    (datetime_create >= "2022-12-07"    and     datetime_create < "2022-12-08")
    )
    and 
    url like "https://level.ru%"
    --and title like "%Нагатинская%"
    --and apartment_floor = 13
    --and apartment_room = 1
    --and apartment_area = '30.5'
    and CAST((price_sale / apartment_area)/100000 as int)<= 1

ORDER BY id desc
limit 2000000
""")

cursor.fetchall()
