# %%
def check_date(day, month, year):
    if day < 1 or day > 31:
        return False
        
    if month < 1 or month > 12:
        return False
        
    if year < 1582 and year > 2024:
        return False
        
    if month in [4, 6, 9, 11] and day > 30:
        return False
        
    elif  month == 2:
        
        if (year % 4 == 0 and year % 100 != 0 ) or year % 400 == 0:
            
            if day > 29 or day > 28:
                return False
    
    return True   

day = 3.5
month = 4
year = 2022
if check_date(day, month, year):
    print("Дата корректна")
else:
    print("Дата некорректна")
# Out:
# Дата корректна

# %%
def move(time):
"""
для каждого проеханного метра будем два раза печатать вперед
"""
    if(time%5==0):
        print("Вперед "*2)

def turn(angle):
"""
так как у нас тут все повороты кратны 90, можно вот так написать конвертер для поворота
"""
        rot = (360 - angle)/90
        print("Поворот "*int(rot))

def walk(len):
    time = len / 0.2 
    for i in range(int(time+1)):
        move(i)

        

def to_left():
    turn(90)

def to_right():
    turn(270)

def to_around():
    turn(180)

def robo_bread():
    to_left()
    walk(25)
    to_right()
    walk(23)
    to_right()
    walk(8)
    to_around()
    walk(8)
    to_left()
    walk(23)
    to_left()
    walk(25)
    #print("End")


robo_bread()
# Out:
# Поворот Поворот Поворот
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Поворот
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Поворот
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# Вперед Вперед
# ...
