# %% [markdown]
# # Найти иголку в стоге сена

# %% [markdown]
# Найдите длину списка stog_sena

# %%
stog_sena = ["сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","иголка","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено","сено"]

# %%
# len(stog_sena)

# %% [markdown]
# Посчитайте сколько всего "сено" в stog_sena

# %%
# stog_sena.count("сено")

# %% [markdown]
# Найдите индекс "иголка" в списке stog_sena

# %%
# stog_sena.index("иголка")

# %% [markdown]
# Достаньте "иголка" из stog_sena в переменную igolka

# %%
# igolka = stog_sena.pop(666)

# %%
# igolka

# %% [markdown]
# Ах да, совсем забыл сказать!
# Вы, Кощей Бессмертный, но это не надолго, если Вы не спрячете иголку!
# Я Вам напомню, где Вы должны ее спрятать:
#
# Игла в яйце, яйцо в утке, утка в зайце, заяц спрятан в ларце, ларец в дубу, который растёт в чёрной горе.

# %%
chernaya_gora = []
dub = []
larez = []
zayaz = []
utka = []
yaizo = []

# %%
# yaizo.append(igolka)

# %%
# utka.append(yaizo)

# %%
# zayaz.append(utka)

# %%
# larez.append(zayaz)

# %%
# dub.append(larez)

# %%
# chernaya_gora.append(dub)

# %% [markdown]
# Проверьте, хороши ли вы спрятали иголку? ([[[[['иголка']]]]])

# %%
dub
# Out:
# []
