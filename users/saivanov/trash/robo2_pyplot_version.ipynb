# %%
#попробую написать визуализацию движения робота из второго задания, у него очень простой язык - продвижение на 0.5 по команде "вперед" и 
#поворот на -90 градусов по команде "поворот"
#ещё наверное надо сделать ему какое-то задание начального положения и направления. положение буду задавать координатами, направление - север, запад, юг, восток - то, 
#куда он поедет по команде вперед

# %%
class Robo:
    """
    Класс, помогающий запилить движение робота по заданной программе
    """
    def __init__(self,position:tuple = (0,0), direction:str = "север")->None:
        """
        инициализация. задаем начальные коодинаты и направление
        """
        self.__X = position[0]
        self.__Y = position[1]
        self.__possible_directions = {"север":(0,1),"восток":(1,0),"юг":(0,-1),"запад":(-1,0),}
        self.__program = []
        self.__leg_lenght = 0.5
        if direction.lower() in self.__possible_directions:
            self.__direction = direction
        else: #поехали на север если какую-то дичь задали вместо направления
            self.__direction = "север"
        print(f"Робот установлен в ({self.__X}, {self.__Y}) и готов ехать на {self.__direction}")
    
    def set_program(self, program: str)->None:
        """
        прочитать и переварить программу
        """
        lowered_program = program.lower()
        list_program = lowered_program.split()
        if set(list_program) == {"вперед", "поворот"}:
            self.__program = list_program[:]
            print("Программа прочитана успешно")
            #print(self.__program)
        else:
            print("Введенная программа содержит недопустимые инструкции")

    def __rotate(self)->None:
        """
        вспомогательный метод для команды "поворот"
        что-то тут плохо, но получше придумать не могу
        даже один раз придумал, потом опять забыл
        """
        if "север" == self.__direction:
            self.__direction = "восток"
        elif "восток" == self.__direction:
            self.__direction = "юг"
        elif "юг" == self.__direction:
            self.__direction = "запад"
        elif "запад" == self.__direction:
            self.__direction = "север"    
    def __do_step(self)->None:
        """
        вспомогательный метод для команды "вперед"
        """
        self.__X += self.__leg_lenght*(self.__possible_directions[self.__direction])[0]
        self.__Y += self.__leg_lenght*(self.__possible_directions[self.__direction])[1]
    
    def move(self)->tuple :
        """
        робот выполняет одно движение по программе
        """
        if self.__program:
            action = self.__program.pop(0)
        if action == "вперед":
            self.__do_step()
        if action == "поворот":
            self.__rotate()
        return (self.__X,self.__Y)            
    
    
    def is_job_done(self)->bool :
        """
        сигнализирует об окончании выполнении программы
        """
        result = False
        if len(self.__program) == 0:
            result = True
        return result    

#проверка работоспособности
#robo2 = Robo((1,1), "юг")
#robo2.set_program("вперед вперед поворот вперед поворот")
#while not robo2.is_job_done():
#    print(robo2.move())

# %%
#дом, здание и булочную нарисую тоже роботами
robo_home_program = "поворот " + "вперед "*2 + "поворот " + "вперед "*2 + "поворот " + "вперед "*4 + "поворот " + "вперед "*2 + "поворот " + "вперед "*2 
robo_building_program = "поворот " + "вперед "*50 + "поворот " + "вперед "*45 + "поворот " + "вперед "*70 + "поворот " + "вперед "*45 + "поворот " + "вперед "*20 
robo_bakery_program = "поворот " + "вперед "*2 + "поворот " + "вперед "*2 + "поворот " + "вперед "*4 + "поворот " + "вперед "*2 + "поворот " + "вперед "*2

# %%
"""
здесь нужно задать программу для робота, который идет за хлебом
"""
robo_walker_program = """
Поворот Поворот Поворот Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Поворот Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Поворот Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Поворот Поворот Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Поворот Поворот Поворот Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Поворот Поворот Поворот Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед Вперед  
"""

robo_walker_program = """
Поворот Поворот Поворот 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Поворот 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Поворот 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Поворот Поворот 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Поворот Поворот Поворот 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Поворот Поворот Поворот 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед 
Вперед Вперед
"""

robo_walker_program = """
Поворот
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Поворот
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Поворот
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Поворот
Поворот
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Поворот
Поворот
Поворот
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Поворот
Поворот
Поворот
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Поворот
Поворот
Поворот
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Поворот
Поворот
Поворот
"""

# %%
print((robo_walker_program.count(' '))+1)
# Out:
# 1

# %%
#pyplot версия
import matplotlib.pyplot as plt
#from time import sleep
#робот, рисующий дом
robo_home = Robo((0,0), "юг")
robo_home.set_program(robo_home_program)
#робот, рисующий здание (или забор)
robo_building = Robo((0,0), "юг")
robo_building.set_program(robo_building_program)
#робот, рисующий булочную
robo_bakery = Robo((-17,22.5), "север")
robo_bakery.set_program(robo_bakery_program)
"""
робот, идущий за хлебом
"""
#задаем начальное положение и направление
robo_walker = Robo((0,0), "юг")
#задаем программу
robo_walker.set_program(robo_walker_program)
robo_home_traj = {"x":[],"y":[]}
robo_bakery_traj ={"x":[],"y":[]}
robo_building_traj = {"x":[],"y":[]}
robo_walker_traj = {"x":[],"y":[]}
while not robo_home.is_job_done():
    x,y = robo_home.move()
    robo_home_traj["x"].append(x)
    robo_home_traj["y"].append(y)    
while not robo_bakery.is_job_done():
    x,y = robo_bakery.move()
    robo_bakery_traj["x"].append(x)
    robo_bakery_traj["y"].append(y)
while not robo_building.is_job_done():
    x,y = robo_building.move()
    robo_building_traj["x"].append(x)
    robo_building_traj["y"].append(y)
while not robo_walker.is_job_done():
    x,y = robo_walker.move()
    robo_walker_traj["x"].append(x)
    robo_walker_traj["y"].append(y)

plt.plot (robo_home_traj["x"], robo_home_traj["y"])
plt.plot (robo_bakery_traj["x"], robo_bakery_traj["y"])
plt.plot (robo_building_traj["x"], robo_building_traj["y"])
plt.plot (robo_walker_traj["x"], robo_walker_traj["y"])

plt.draw()
# Out:
# Робот установлен в (0, 0) и готов ехать на юг
# Программа прочитана успешно
# Робот установлен в (0, 0) и готов ехать на юг
# Программа прочитана успешно
# Робот установлен в (-17, 22.5) и готов ехать на север
# Программа прочитана успешно
# Робот установлен в (0, 0) и готов ехать на юг
# Программа прочитана успешно

# %%
len("""Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед
Вперед""".split())
# Out:
# 20
