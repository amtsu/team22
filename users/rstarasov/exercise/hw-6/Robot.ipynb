# %% [markdown]
# Составим модель задачи:
# Робот должен самостоятельно выехать из дома, добраться до булочной, развернуться и поехать в обратном направлении до дома.

# %% [markdown]
# Алгоритм:
# 1. Робот выезжает из дома прямо на 0.5м, поворачивает направо.
# 2. Едет до первого поворота 25.5м и поворачивает направо.
# 3. Едет до второго поворота 23.5м и поворачивает направо.
# 4. Едет еще 8.5м до булочной.
# 5. Теперь робот разворачивается в обратном направлении через два поворота.
# 6. Едет 8.5м до поворота и исполняет три поворота направо.
# 7. Едет 23.5м до следующего поворота и исполняет три поворота.
# 8. Едет 25.5 метров до дома и исполняет три поворота.
# 9. Едет 0.5м до порога.

# %% [markdown]
# Программа №1:
# 1) Выехать из дома:
# 1. вперед
# 1. поворот
# 2) Добраться до первого поворота:
# 1. Вперед
# 2. Вперед
# 3. Вперед
# 4. Вперед
# 5. Вперед
# 6. Вперед
# 7. Вперед
# 8. Вперед
# 9. Вперед
# 10. Вперед
# 11. Вперед
# 12. Вперед
# 13. Вперед
# 14. Вперед
# 15. Вперед
# 16. Вперед
# 17. Вперед
# 18. Вперед
# 19. Вперед
# 20. Вперед
# 21. Вперед
# 22. Вперед
# 23. Вперед
# 24. Вперед
# 25. Вперед
# 26. Вперед
# 27. Вперед
# 28. Вперед
# 29. Вперед
# 30. Вперед
# 31. Вперед
# 32. Вперед
# 33. Вперед
# 34. Вперед
# 35. Вперед
# 36. Вперед
# 37. Вперед
# 38. Вперед
# 39. Вперед
# 40. Вперед
# 41. Вперед
# 42. Вперед
# 43. Вперед
# 44. Вперед
# 45. Вперед
# 46. Вперед
# 47. Вперед
# 48. Вперед
# 49. Вперед
# 50. Вперед
# 51. Вперед
# 1. Поворот
# 3) Добраться до второго поворота:
# 1. Вперед
# 2. Вперед
# 3. Вперед
# 4. Вперед
# 5. Вперед
# 6. Вперед
# 7. Вперед
# 8. Вперед
# 9. Вперед
# 10. Вперед
# 11. Вперед
# 12. Вперед
# 13. Вперед
# 14. Вперед
# 15. Вперед
# 16. Вперед
# 17. Вперед
# 18. Вперед
# 19. Вперед
# 20. Вперед
# 21. Вперед
# 22. Вперед
# 23. Вперед
# 24. Вперед
# 25. Вперед
# 26. Вперед
# 27. Вперед
# 28. Вперед
# 29. Вперед
# 30. Вперед
# 31. Вперед
# 32. Вперед
# 33. Вперед
# 34. Вперед
# 35. Вперед
# 36. Вперед
# 37. Вперед
# 38. Вперед
# 39. Вперед
# 40. Вперед
# 41. Вперед
# 42. Вперед
# 43. Вперед
# 44. Вперед
# 45. Вперед
# 46. Вперед
# 47. Вперед
# 1. Поворот
# 4) Доехать до булочной:
# 1. Вперед
# 2. Вперед
# 3. Вперед
# 4. Вперед
# 5. Вперед
# 6. Вперед
# 7. Вперед
# 8. Вперед
# 9. Вперед
# 10. Вперед
# 11. Вперед
# 12. Вперед
# 13. Вперед
# 14. Вперед
# 15. Вперед
# 16. Вперед
# 17. Вперед
# 5) Едем обратно до угла дома и поворачиваем:
# 1. Поворот
# 2. Поворот
# 1. Вперед
# 2. Вперед
# 3. Вперед
# 4. Вперед
# 5. Вперед
# 6. Вперед
# 7. Вперед
# 8. Вперед
# 9. Вперед
# 10. Вперед
# 11. Вперед
# 12. Вперед
# 13. Вперед
# 14. Вперед
# 15. Вперед
# 16. Вперед
# 17. Вперед
# 1. Поворот
# 2. Поворот
# 3. Поворот
# 6) Едем до второго угла и поворачиваем:
# 1. Вперед
# 2. Вперед
# 3. Вперед
# 4. Вперед
# 5. Вперед
# 6. Вперед
# 7. Вперед
# 8. Вперед
# 9. Вперед
# 10. Вперед
# 11. Вперед
# 12. Вперед
# 13. Вперед
# 14. Вперед
# 15. Вперед
# 16. Вперед
# 17. Вперед
# 18. Вперед
# 19. Вперед
# 20. Вперед
# 21. Вперед
# 22. Вперед
# 23. Вперед
# 24. Вперед
# 25. Вперед
# 26. Вперед
# 27. Вперед
# 28. Вперед
# 29. Вперед
# 30. Вперед
# 31. Вперед
# 32. Вперед
# 33. Вперед
# 34. Вперед
# 35. Вперед
# 36. Вперед
# 37. Вперед
# 38. Вперед
# 39. Вперед
# 40. Вперед
# 41. Вперед
# 42. Вперед
# 43. Вперед
# 44. Вперед
# 45. Вперед
# 46. Вперед
# 47. Вперед
# 1. Поворот
# 2. Поворот
# 3. Поворот
# 7) Поворачиваем, едем до дома и заезжаем домой:
# 1. Вперед
# 2. Вперед
# 3. Вперед
# 4. Вперед
# 5. Вперед
# 6. Вперед
# 7. Вперед
# 8. Вперед
# 9. Вперед
# 10. Вперед
# 11. Вперед
# 12. Вперед
# 13. Вперед
# 14. Вперед
# 15. Вперед
# 16. Вперед
# 17. Вперед
# 18. Вперед
# 19. Вперед
# 20. Вперед
# 21. Вперед
# 22. Вперед
# 23. Вперед
# 24. Вперед
# 25. Вперед
# 26. Вперед
# 27. Вперед
# 28. Вперед
# 29. Вперед
# 30. Вперед
# 31. Вперед
# 32. Вперед
# 33. Вперед
# 34. Вперед
# 35. Вперед
# 36. Вперед
# 37. Вперед
# 38. Вперед
# 39. Вперед
# 40. Вперед
# 41. Вперед
# 42. Вперед
# 43. Вперед
# 44. Вперед
# 45. Вперед
# 46. Вперед
# 47. Вперед
# 48. Вперед
# 49. Вперед
# 50. Вперед
# 51. Вперед
# 1. Поворот
# 2. Поворот
# 3. Поворот
# 1. Вперед

# %%
#Программа №2:
go = 'Вперед'
turn = 'Поворот'

#Выехать из дома:
go
turn
#Добраться до первого поворота:
go * 51
turn
#Добраться до второго поворота:
go * 47
turn
#Доехать до булочной:
go * 17
#Едем обратно до угла дома и поворачиваем:
turn * 2
go * 17
turn * 3
#Едем до второго угла и поворачиваем:
go * 47
turn * 3
#Поворачиваем, едем до дома и заезжаем домой:
go * 51
turn * 3
go
# Out:
# 'Вперед'

# %%
#Программа №3:
#0.5метра = 2.5 секунд:
go = 2.5
#Записываем в переменную "поворот" поворот на 90 градусов:
turn = 90
#и копируем все из предыдущей задачи:

#Выехать из дома:
go
turn
#Добраться до первого поворота:
go * 51
turn
#Добраться до второго поворота:
go * 47
turn
#Доехать до булочной:
go * 17
#Едем обратно до угла дома и поворачиваем:
turn * 2
go * 17
turn * 3
#Едем до второго угла и поворачиваем:
go * 47
turn * 3
#Поворачиваем, едем до дома и заезжаем домой:
go * 51
turn * 3
go
# Out:
# 2.5

# %% [markdown]
# Пятое задание я не понимаю, но запишу ответ с условием моей интерпритации:
# После выполнения одной домашней работы, сходи в булочную за углом и купи хлеба. Можешь посмотреть дорогу в приложении с картами.
