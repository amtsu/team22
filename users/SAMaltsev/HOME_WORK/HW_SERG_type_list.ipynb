# %% [markdown]
# # №1 Задание: создайте список дел.
#
# **Пример списка с 2 делами:**
#
#
# <center>
#     <table>
#         <tr>
#             <td>
#                 №
#             </td>
#             <td>
#                 Дело
#             </td>
#             <td>
#                 Дата до котрой нужно сделать
#             </td>
#             <td>
#                 Дата когда было сделано
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Дело №1
#             </td>
#             <td>
#                 купить хлеб
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Дело №2
#             </td>
#             <td>
#                 помыть полы
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#             <td>
#                 -
#             </td>
#         </tr>
#     </table>
# </center>
#
# Рекомендуемый размер списка 22 элемента.
#
# После создания списка дел.
# * Нужно посчитать общее количество дел в списке.
# * Напечатать все дела
# * Напечатать только 2 и 5 дело

# %%
matrix_22=[[[[[[[[[[[[[[[[[[[[[[["дело #1", "хлеб", "01-01-2001", "01-02_2001"],["дело #2", "гараж", "01-01-2001", "01-02_2001"],["дело #3", "свет", "01-01-2001", "01-02_2001"],["дело #4", "газ", "01-01-2001", "01-02_2001"],["дело #5", "листья", "01-01-2001", "01-02_2001"],["дело #6", "гараж", "01-01-2001", "01-02_2001"],["дело #7", "сани", "01-01-2001", "01-02_2001"],["дело #8", "ворота", "01-01-2001", "01-02_2001"],["дело #9", "дрова", "01-01-2001", "01-02_2001"],["дело #10", "дерево", "01-01-2001", "01-02_2001"],["дело #11", "озеро", "01-01-2001", "01-02_2001"],["дело #12", "девушка", "01-01-2001", "01-02_2001"],["дело #13", "тетрадь", "01-01-2001", "01-02_2001"],["дело #14", "черепаха", "01-01-2001", "01-02_2001"],["дело #15", "пятерка", "01-01-2001", "01-02_2001"],["дело #16", "шарик", "01-01-2001", "01-02_2001"],["дело #17", "сумка", "01-01-2001", "01-02_2001"],["дело #18", "вероятность", "01-01-2001", "01-02_2001"],["дело #19", "драндулет", "01-01-2001", "01-02_2001"],["дело #20", "дека", "01-01-2001", "01-02_2001"],["дело #21", "доярка", "01-01-2001", "01-02_2001"],["дело #22", "дробь", "01-01-2001", "01-02_2001"]]]]]]]]]]]]]]]]]]]]]]]

# %%
matrix_22[1][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 matrix_22[1][1]
#
# IndexError: list index out of range

# %%
#здесь хочется создать список дел какой-то функцией, но наверно рано

# %%
matrix2=[[["дело #1", "хлеб", "01-01-2001", "01-02_2001"],["дело #2", "бред", "01-01-2001", "01-02_2001"],["дело #3", "свет", "01-01-2001", "01-02_2001"]]]

# %%
matrix2[1][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 matrix2[1][1]
#
# IndexError: list index out of range

# %%
matrix = [[["дело #1", "хлеб", "01-01-2001", "01-02_2001"],["дело #2", "бред", "01-04-2001", "01-02_2001"],["дело #3", "бред", "01-04-2001", "01-02_2001"]]]
matrix[1][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [53], line 2
#       1 matrix = [[["дело #1", "хлеб", "01-01-2001", "01-02_2001"],["дело #2", "бред", "01-04-2001", "01-02_2001"],["дело #3", "бред", "01-04-2001", "01-02_2001"]]]
# ----> 2 matrix[1][1]
#
# IndexError: list index out of range

# %%
#потратив кучу времени на устранение бессмыленных ошибок, я решил все же использовать append и создать все с нуля, обновляя list3 после каждого добавления

# %%
matrix1 =[["дело #1", "хлеб", "01-01-2001", "01-02_2001"],["дело #2", "бред", "01-04-2001", "01-02_2001"]]

# %%
matrix1
# Out:
# [['дело #1', 'хлеб', '01-01-2001', '01-02_2001'],
#  ['дело #2', 'бред', '01-04-2001', '01-02_2001']]

# %%
list3=["дело #3", "В", "01-04-2001", "01-02_2001"]
list4=["дело #4", "Г", "01-04-2001", "01-02_2001"]
list5=["дело #5", "Д", "01-04-2001", "01-02_2001"]
list6=["дело #6", "Е", "01-04-2001", "01-02_2001"]
list7=["дело #7", "Ж", "01-04-2001", "01-02_2001"]
list8=["дело #8", "З", "01-04-2001", "01-02_2001"]
list9=["дело #9", "И", "01-04-2001", "01-02_2001"]
list10=["дело #10", "Кбред", "01-04-2001", "01-02_2001"]
list11=["дело #11", "Лбред", "01-04-2001", "01-02_2001"]
list12=["дело #12", "Мбред", "01-04-2001", "01-02_2001"]
list13=["дело #13", "Нбред", "01-04-2001", "01-02_2001"]
list14=["дело #14", "Обред", "01-04-2001", "01-02_2001"]
list15=["дело #15", "Пбред", "01-04-2001", "01-02_2001"]
list16=["дело #16", "Рбред", "01-04-2001", "01-02_2001"]
list17=["дело #17", "Сбред", "01-04-2001", "01-02_2001"]
list18=["дело #18", "Тбред", "01-04-2001", "01-02_2001"]
list19=["дело #19", "Убред", "01-04-2001", "01-02_2001"]
list20=["дело #20", "Фбред", "01-04-2001", "01-02_2001"]
list21=["дело #21", "Хбред", "01-04-2001", "01-02_2001"]
list22=["дело #22", "Цбред", "01-04-2001", "01-02_2001"]

# %%
matrix1.append(list3)
matrix1.append(list4)
matrix1.append(list5)
matrix1.append(list6)
matrix1.append(list7)
matrix1.append(list8)
matrix1.append(list9)
matrix1.append(list10)
matrix1.append(list11)
matrix1.append(list12)
matrix1.append(list13)
matrix1.append(list14)
matrix1.append(list15)
matrix1.append(list16)
matrix1.append(list17)
matrix1.append(list18)
matrix1.append(list19)
matrix1.append(list20)
matrix1.append(list21)
matrix1.append(list22)

# %%
print(matrix1[1][1])
print(matrix1[4][1])
# Out:
# бред
# Д

# %%
#количество дел:

# %%
len(matrix1)
# Out:
# 22

# %%
matrix1[0:22]
# Out:
# [['дело #1', 'хлеб', '01-01-2001', '01-02_2001'],
#  ['дело #2', 'бред', '01-04-2001', '01-02_2001'],
#  ['дело #3', 'В', '01-04-2001', '01-02_2001'],
#  ['дело #4', 'Г', '01-04-2001', '01-02_2001'],
#  ['дело #5', 'Д', '01-04-2001', '01-02_2001'],
#  ['дело #6', 'Е', '01-04-2001', '01-02_2001'],
#  ['дело #7', 'Ж', '01-04-2001', '01-02_2001'],
#  ['дело #8', 'З', '01-04-2001', '01-02_2001'],
#  ['дело #9', 'И', '01-04-2001', '01-02_2001'],
#  ['дело #10', 'Кбред', '01-04-2001', '01-02_2001'],
#  ['дело #11', 'Лбред', '01-04-2001', '01-02_2001'],
#  ['дело #12', 'Мбред', '01-04-2001', '01-02_2001'],
#  ['дело #13', 'Нбред', '01-04-2001', '01-02_2001'],
#  ['дело #14', 'Обред', '01-04-2001', '01-02_2001'],
#  ['дело #15', 'Пбред', '01-04-2001', '01-02_2001'],
#  ['дело #16', 'Рбред', '01-04-2001', '01-02_2001'],
#  ['дело #17', 'Сбред', '01-04-2001', '01-02_2001'],
#  ['дело #18', 'Тбред', '01-04-2001', '01-02_2001'],
#  ['дело #19', 'Убред', '01-04-2001', '01-02_2001'],
# ...

# %%
a=['mom', 500, 'dad', 1000, 'brother', 746, 'me', 2000][4]
print(a)
# Out:
# brother

# %%
# extend в начале
# append в конце

# %%
savings_family.extend("Harry")
print(savings_family)
# Out:
# ['mom', 500, 'dad', 1000, 'brother', 746, 'me', 2000, 5, 'H', 'a', 'r', 'r', 'y', 'H', 'a', 'r', 'r', 'y']

# %%
#почему extend раскладывает Harry по буквам и в конце ?

# %% [markdown]
# # №2 Задание: создайте список расхдов и доходов.
#
# **Пример списка доходов и расходов**
#
# <center>
#     <table>
#         <tr>
#             <td>
#                 №
#             </td>
#             <td>
#                 Описание
#             </td>
#             <td>
#                 Сумма
#             </td>
#             <td>
#                 Дата
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 №1
#             </td>
#             <td>
#                 купил хлеб
#             </td>
#             <td>
#                 -50
#             </td>
#             <td>
#                 09-08-2022
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 №2
#             </td>
#             <td>
#                 купил тапочки
#             </td>
#             <td>
#                 -200
#             </td>
#             <td>
#                 11-08-2022
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 №3
#             </td>
#             <td>
#                 получил зп
#             </td>
#             <td>
#                 50000
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#         </tr>
#     </table>
# </center>
#
# * Рекомендуемый размер списка 22 элемента.
# * добавить к списку еще 2 действия
# * посчитать сколько всего действий в вашем списке

# %%
spisok=[['дело #1', 'хлеб', '01-01-2001', '01-02_2001'],
 ['дело #2', 'бред', '01-04-2001', '01-02_2001'],
 ['дело #3', 'В', '01-04-2001', '01-02_2001'],
 ['дело #4', 'Г', '01-04-2001', '01-02_2001'],
 ['дело #5', 'Д', '01-04-2001', '01-02_2001'],
 ['дело #6', 'Е', '01-04-2001', '01-02_2001'],
 ['дело #7', 'Ж', '01-04-2001', '01-02_2001'],
 ['дело #8', 'З', '01-04-2001', '01-02_2001'],
 ['дело #9', 'И', '01-04-2001', '01-02_2001'],
 ['дело #10', 'Кбред', '01-04-2001', '01-02_2001'],
 ['дело #11', 'Лбред', '01-04-2001', '01-02_2001'],
 ['дело #12', 'Мбред', '01-04-2001', '01-02_2001'],
 ['дело #13', 'Нбред', '01-04-2001', '01-02_2001'],
 ['дело #14', 'Обред', '01-04-2001', '01-02_2001'],
 ['дело #15', 'Пбред', '01-04-2001', '01-02_2001'],
 ['дело #16', 'Рбред', '01-04-2001', '01-02_2001'],
 ['дело #17', 'Сбред', '01-04-2001', '01-02_2001'],
 ['дело #18', 'Тбред', '01-04-2001', '01-02_2001'],
 ['дело #19', 'Убред', '01-04-2001', '01-02_2001'],
 ['дело #20', 'Фбред', '01-04-2001', '01-02_2001'],
 ['дело #21', 'Хбред', '01-04-2001', '01-02_2001'],
 ['дело #22', 'Цбред', '01-04-2001', '01-02_2001']]

# %%
spisok
# Out:
# [['дело #1', 'хлеб', '01-01-2001', '01-02_2001'],
#  ['дело #2', 'бред', '01-04-2001', '01-02_2001'],
#  ['дело #3', 'В', '01-04-2001', '01-02_2001'],
#  ['дело #4', 'Г', '01-04-2001', '01-02_2001'],
#  ['дело #5', 'Д', '01-04-2001', '01-02_2001'],
#  ['дело #6', 'Е', '01-04-2001', '01-02_2001'],
#  ['дело #7', 'Ж', '01-04-2001', '01-02_2001'],
#  ['дело #8', 'З', '01-04-2001', '01-02_2001'],
#  ['дело #9', 'И', '01-04-2001', '01-02_2001'],
#  ['дело #10', 'Кбред', '01-04-2001', '01-02_2001'],
#  ['дело #11', 'Лбред', '01-04-2001', '01-02_2001'],
#  ['дело #12', 'Мбред', '01-04-2001', '01-02_2001'],
#  ['дело #13', 'Нбред', '01-04-2001', '01-02_2001'],
#  ['дело #14', 'Обред', '01-04-2001', '01-02_2001'],
#  ['дело #15', 'Пбред', '01-04-2001', '01-02_2001'],
#  ['дело #16', 'Рбред', '01-04-2001', '01-02_2001'],
#  ['дело #17', 'Сбред', '01-04-2001', '01-02_2001'],
#  ['дело #18', 'Тбред', '01-04-2001', '01-02_2001'],
#  ['дело #19', 'Убред', '01-04-2001', '01-02_2001'],
# ...

# %%
list23=["дело #23", "В", "01-04-2001", "01-02_2001"]
list24=["дело #24", "Г", "01-04-2001", "01-02_2001"]

# %%
spisok.append(list23)
spisok.append(list24)

# %%
spisok
# Out:
# [['дело #1', 'хлеб', '01-01-2001', '01-02_2001'],
#  ['дело #2', 'бред', '01-04-2001', '01-02_2001'],
#  ['дело #3', 'В', '01-04-2001', '01-02_2001'],
#  ['дело #4', 'Г', '01-04-2001', '01-02_2001'],
#  ['дело #5', 'Д', '01-04-2001', '01-02_2001'],
#  ['дело #6', 'Е', '01-04-2001', '01-02_2001'],
#  ['дело #7', 'Ж', '01-04-2001', '01-02_2001'],
#  ['дело #8', 'З', '01-04-2001', '01-02_2001'],
#  ['дело #9', 'И', '01-04-2001', '01-02_2001'],
#  ['дело #10', 'Кбред', '01-04-2001', '01-02_2001'],
#  ['дело #11', 'Лбред', '01-04-2001', '01-02_2001'],
#  ['дело #12', 'Мбред', '01-04-2001', '01-02_2001'],
#  ['дело #13', 'Нбред', '01-04-2001', '01-02_2001'],
#  ['дело #14', 'Обред', '01-04-2001', '01-02_2001'],
#  ['дело #15', 'Пбред', '01-04-2001', '01-02_2001'],
#  ['дело #16', 'Рбред', '01-04-2001', '01-02_2001'],
#  ['дело #17', 'Сбред', '01-04-2001', '01-02_2001'],
#  ['дело #18', 'Тбред', '01-04-2001', '01-02_2001'],
#  ['дело #19', 'Убред', '01-04-2001', '01-02_2001'],
# ...

# %%
len(spisok)
# Out:
# 24
