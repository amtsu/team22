# %% [raw]
# №2
#
# поворот*3
# вперед*10*2
# поворот*3
# вперед*(1+22,5)*2
# поворот*3
# вперед*(1+27)*2
# поворот*3
# ХЛЕБ
# поворот*3
# вперед*(1+27)*2
# поворот
# вперед*(1+22,5)*2
# поворот
# вперед*10*2

# %% [raw]
# №3
#
# ????????????
#
# поворот*3
# вперед*10*2
# поворот*3
# вперед*(1+22,5)*2
# поворот*3
# вперед*(1+27)*2
# поворот*3
# ХЛЕБ
# поворот*3
# вперед*(1+27)*2
# поворот
# вперед*(1+22,5)*2
# поворот
# вперед*10*2

# %% [raw]
# №4
#
# поворот(270)
# вперед(5*10)
# поворот(270)
# вперед(5*(1+22,5)
# поворот(270)
# вперед(5*(1+27)
# поворот(270)
# ХЛЕБ
# поворот(270)
# вперед(5*(1+27)
# поворот(90)
# вперед(5*(1+22,5)
# поворот(90)
# вперед(5*10

# %% [raw]
# №5
#
# Инстркуция на примере 6 домашки
#
# 1. Подгрузить актуальные файлы домашек с гита
# - git checkout main
# - git pull
# 2. Сделать ветку для новой домашки и переключиться на нее
# - git checkout -b <логин гитхабе>-hw6
# 3. Скопировать папку с домашке себе в папку
# - можно просто копи-пейст
# - можно через команды в консоли: cp -r source_folder destination_folder
# 4. Выполнять задания, создавая и пуша комиты время от времени для подстраховки
# - git add .
# - git commit -m'здесь описать что поменялось'
# - git push
# 5. Как все сделал(а), отправить пулреквест
# - зайти на гитхаб в репозиторий курса
# - нажать create pull request
# - добавить одногруппников и кураторов в ревьюеры
# - добавить метку группы
# 6. Если есть комментарии по пулреквесту, вернуться к 4 шагу
# 7. Увидеть принятый пул реквест на гитхабе
# - радоваться и танцевать
