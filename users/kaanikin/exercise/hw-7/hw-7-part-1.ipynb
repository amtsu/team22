# %% [markdown]
# <h1>Функции, циклы, условные операторы </h1>

# %%
'''
Задание 1. Написать функцию для вывода двумерной матрицы по столбцам, 
не используя индексацию (с помощью [] или любым другим способом получения
элемента по заданному индексу).
Функция должна принимать на вход список и ничего не возвращать
'''

def print_matrix(matrix):
    
   
    for row in matrix:
        for element in row:
           print(element, end=' ')
        print()

#проверка        
matrix1 = [[1,4,7,],[2,5,8,],[3,6,9,]]
matrix2 = [[1,4,7,10],[2,5,8,11],[3,6,9,12]]
matrix3 = [[1,3,5,7],[2,4,6,8],]
matrix4 = [[1,2,],[5,6,],[9,10,]]
matrix5 = [[1,2,3],]
matrix6 = []

print_matrix(matrix1)
print("="*30)
print_matrix(matrix2)
print("="*30)
print_matrix(matrix3)
print("="*30)
print_matrix(matrix4)
print("="*30)
print_matrix(matrix5)
print("="*30)
print_matrix(matrix6)
# Out:
# 1 4 7
# 2 5 8
# 3 6 9
# ==============================
# 1 4 7 10
# 2 5 8 11
# 3 6 9 12
# ==============================
# 1 3 5 7
# 2 4 6 8
# ==============================
# 1 2
# 5 6
# 9 10
# ==============================
# 1 2 3
# ==============================

# %%
'''
Задание 2. Напишите функцию, вызывающую саму себя 10 раз;
функция должна вызываться как ten_times() и ничего не возвращать;
'''
def ten_times(iter):
     
   
        
        if iter > 0:
            print('Вызов ' + str(10-iter+1))
            ten_times(iter-1)
        else:
            return
       

#проверка
ten_times(10)
# Out:
# Вызов 1
# Вызов 2
# Вызов 3
# Вызов 4
# Вызов 5
# Вызов 6
# Вызов 7
# Вызов 8
# Вызов 9
# Вызов 10

# %%
'''
Задание 3.
'''
# дан отрывок кода
a_haiku = ["Всё глазел на них",
"Сакуры цветы, пока",
"Шею не свело"]

def print_haiku(haiku):
    for line in haiku:
        print(line)

print_haiku(a_haiku)

def haiku_upper(haiku):
    for line in haiku:
        print(line.upper())

haiku_upper(a_haiku)    

def third_letter(haiku):
    for line in haiku:
        print(line[2::3])

third_letter(a_haiku)    

def haiku_red(haiku):
    for line in haiku:
        print("\033[91m{}".format(line))

haiku_red(a_haiku)    
   
#'''
#Модифицируйте функцию функцией print_haiku таким образом, чтобы можно было 
#выполнять произвольное преобразование над выводом строк.
#Посторайтесь сильно не менять код print_haiku()
#Выведите с помощью модифицированной функции print_haiku все строки хайку :
# - заглавными буквами
# - только каждый третий символ строк
# - красным цветом (https://habr.com/ru/sandbox/158854/, первый раздел)'''
# Out:
# Всё глазел на них
# Сакуры цветы, пока
# Шею не свело
# ВСЁ ГЛАЗЕЛ НА НИХ
# САКУРЫ ЦВЕТЫ, ПОКА
# ШЕЮ НЕ СВЕЛО
# ёленн
# кывыпа
# юево
# Всё глазел на них
# Сакуры цветы, пока
# Шею не свело

# %%
'''
Задание 4. Напишите простой пользовательский интерфейс к заданию 3.
Пользователю должно выдаваться сообщение о возможностях вывода (меню), и приглашение на ввод
идентификатора действия или символа `q` для выхода, например

Возможные действия:
1 - вывод хайку заглавными буквами
2 - вывод только третьих символов каждой строки хайку
3 - вывод хайку красным цветом
Введите номер действия или q для выхода: 

После ввода идентификатора действия, необходимо выполнить соответствующее действие 
и снова вывести меню с запросом на ввод. в случае некорректного идентификатора действия 
вывести соответствующее сообщение и снова вывести меню. После ввода q завершить работу с
простым пользовательским интрефейсом

'''


   

def haiku_mod(haiku):
    
    while True:
        print('\n')
        your_answer = input("""Что вы хотите сделать:
            1 - вывод хайку заглавными буквами
            2 - вывод только третьих символов каждой строки хайку
            3 - вывод хайку красным цветом
            Введите номер действия или q для завершения:""")    
        print(your_answer)
    
        if your_answer == '1':
            haiku_upper(a_haiku)
            
    
        elif your_answer == '2':
            third_letter(a_haiku)
            
    
        elif your_answer == '3':
            haiku_red(a_haiku)
            
    
        
        elif your_answer == 'q':
            print("Hasta la vista, baby!")
            break
    
        else:
            print("Введите значение из предложенных")
        

haiku_mod(a_haiku)
# Out:
# Что вы хотите сделать:
#             1 - вывод хайку заглавными буквами
#             2 - вывод только третьих символов каждой строки хайку
#             3 - вывод хайку красным цветом
#             Введите номер действия или q для завершения: q
# q
# Hasta la vista, baby!

# %%
####'''
#Задание 5.
##Дополните функционал задания 3 одним из следующих способов вывода хайку:
##- каждое слово в строке различным цветом,
##- в каждой строке второе слово жирным шрифтом,
##- маленькими буквами синим цветом,
##при этом текст функции print_haiku() меняться не должен. Если такая доработка потребует
#его изменения, пересмотрите дизайн функции print_haiku(), чтобы расширение функионала вывода
#не требовало изменения print_haiku()
#Добавьте в интерфейс, созданный в задании 4 созданный новый способ вывода. Оцените объем и 
#удобство модификации, при необходимости пересмотрите дизайн кода интерфейса для упрощения его 
#изменекния.
#
#'''

def mix_color(haiku):
    
    start_color = "\033[31m"
    color = 30
    for line in haiku:   
        result = ''
        for word in line.split():
            result += f"\033[{color}m{word} "
            color+=1
        print(result)

def bold_second_word(haiku):
    for line in haiku:
        lane = line.split()
        
        formatted_line = ""
        for i in range(len(lane)):
            if (i == 0) or (i % 2) == 0:
                formatted_line += "\033[0m" + lane[i] + ' ' 
            else:
                formatted_line += "\033[1m" + lane[i] + ' '
    
        print(formatted_line)    

def lower_blue(haiku):
    for line in haiku:
        print("\033[34m{}".format(line))

#def bold_second_word(haiku):
    
def haiku_var3(haiku):
    while True:
        print('\n')
        your_answer = input("""Что вы хотите сделать:
            1 - вывод хайку заглавными буквами
            2 - вывод только третьих символов каждой строки хайку
            3 - вывод хайку красным цветом
            4 - вывод каждого слова в строке различным цветом
            5 - вывод в каждой строке второого слова жирным шрифтом
            6 - вывод маленькими буквами синим цветом       
            
            Введите номер действия или q для завершения:""")    
        print(your_answer)
    
        if your_answer == '1':
            haiku_upper(haiku)
            
    
        elif your_answer == '2':
            third_letter(haiku)
            
    
        elif your_answer == '3':
            haiku_red(haiku)
            
        elif your_answer == '4':
            mix_color(haiku)
        
        elif your_answer == '5':
            bold_second_word(haiku) 

        elif your_answer == '6':
            lower_blue(haiku)    
        
        elif your_answer == 'q':
            print("Hasta la vista, baby!")
            break
    
        else:
            print("Введите значение из предложенных")
        

haiku_var3(a_haiku)
# Out:
# Что вы хотите сделать:
#             1 - вывод хайку заглавными буквами
#             2 - вывод только третьих символов каждой строки хайку
#             3 - вывод хайку красным цветом
#             4 - вывод каждого слова в строке различным цветом
#             5 - вывод в каждой строке второого слова жирным шрифтом
#             6 - вывод маленькими буквами синим цветом
#
#             Введите номер действия или q для завершения: 5
# 5
# Всё глазел на них
# Сакуры цветы, пока
# Шею не свело
# Что вы хотите сделать:
#             1 - вывод хайку заглавными буквами
#             2 - вывод только третьих символов каждой строки хайку
#             3 - вывод хайку красным цветом
#             4 - вывод каждого слова в строке различным цветом
#             5 - вывод в каждой строке второого слова жирным шрифтом
#             6 - вывод маленькими буквами синим цветом
#
#             Введите номер действия или q для завершения: 4
# 4
# Всё глазел на них
# Сакуры цветы, пока
# Шею не свело
# Что вы хотите сделать:
#             1 - вывод хайку заглавными буквами
#             2 - вывод только третьих символов каждой строки хайку
#             3 - вывод хайку красным цветом
#             4 - вывод каждого слова в строке различным цветом
#             5 - вывод в каждой строке второого слова жирным шрифтом
#             6 - вывод маленькими буквами синим цветом
#
#             Введите номер действия или q для завершения: 6
# 6
# Всё глазел на них
# Сакуры цветы, пока
# Шею не свело
# Что вы хотите сделать:
#             1 - вывод хайку заглавными буквами
#             2 - вывод только третьих символов каждой строки хайку
#             3 - вывод хайку красным цветом
#             4 - вывод каждого слова в строке различным цветом
#             5 - вывод в каждой строке второого слова жирным шрифтом
#             6 - вывод маленькими буквами синим цветом
#
#             Введите номер действия или q для завершения: 2
# 2
# ёленн
# кывыпа
# юево
# Что вы хотите сделать:
#             1 - вывод хайку заглавными буквами
#             2 - вывод только третьих символов каждой строки хайку
#             3 - вывод хайку красным цветом
#             4 - вывод каждого слова в строке различным цветом
#             5 - вывод в каждой строке второого слова жирным шрифтом
#             6 - вывод маленькими буквами синим цветом
#
#             Введите номер действия или q для завершения: 1
# 1
# ВСЁ ГЛАЗЕЛ НА НИХ
# САКУРЫ ЦВЕТЫ, ПОКА
# ШЕЮ НЕ СВЕЛО
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 88
#      84         else:
#      85             print("Введите значение из предложенных")
# ---> 88 haiku_var3(a_haiku)
#
# Cell In[50], line 49, in haiku_var3(haiku)
#      47 while True:
#      48     print('\n')
# ---> 49     your_answer = input("""Что вы хотите сделать:
#      50         1 - вывод хайку заглавными буквами
#      51         2 - вывод только третьих символов каждой строки хайку
#      52         3 - вывод хайку красным цветом
#      53         4 - вывод каждого слова в строке различным цветом
#      54         5 - вывод в каждой строке второого слова жирным шрифтом
#      55         6 - вывод маленькими буквами синим цветом
#      56
#      57         Введите номер действия или q для завершения:""")
#      58     print(your_answer)
#      60     if your_answer == '1':
#
# File /opt/tljh/user/lib/python3.10/site-packages/ipykernel/kernelbase.py:1270, in Kernel.raw_input(self, prompt)
#    1268     msg = "raw_input was called, but this frontend does not support input requests."
#    1269     raise StdinNotImplementedError(msg)
# -> 1270 return self._input_request(
#    1271     str(prompt),
#    1272     self._parent_ident["shell"],
#    1273     self.get_parent("shell"),
#    1274     password=False,
#    1275 )
#
# File /opt/tljh/user/lib/python3.10/site-packages/ipykernel/kernelbase.py:1313, in Kernel._input_request(self, prompt, ident, parent, password)
#    1310 except KeyboardInterrupt:
#    1311     # re-raise KeyboardInterrupt, to truncate traceback
#    1312     msg = "Interrupted by user"
# -> 1313     raise KeyboardInterrupt(msg) from None
#    1314 except Exception:
#    1315     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
