# %% [markdown]
# Задание 15 часть 1.
# Написать утилиту на языке Python, для редактирования информации в файлах
# team22/library/streams/2024/visits_status.csv и team22/library/streams/2024/hw_status.csv
#
# Утилита должна помогать вам заполнять информацию о выполнении дз и посещении лекций,
# минимальный функционал:
#  - возможность прочитать файлы visits_status.csv и hw_status.csv как csv-формат
#  - возможность редактировать значение статуса для определенной даты или номера hw_status
#  - возможность сохранения валидного для github csv-формата -
# 		* разделители - запятые (,)
# 		* количество "колонок" одинаково для всех "строчек"

# %%
pwd
# Out:
# '/home/jupyter-andromary/github/team22/users/mvandreeva/study2024/exercise/hw15'

# %%
# !git branch
# Out:
#   main
#   mvandreeva-hw11
#   mvandreeva-hw12
# * mvandreeva-hw15
#   mvandreeva-hw8
#   mvandreeva-hw9

# %%
# !git che
# Out:
#   Cell In[3], line 1
#     git branch
#         ^
# SyntaxError: invalid syntax

# %%
Переключаемся на ветку main
Подтягиваем последние изменения git pull
Открываем файл /home/jupyter-andromary/github/team22/library/streams/2024/hw_status.csv
Находим строку со своим ником (изучаем работы с csv)

# %%
cd /home/jupyter-andromary/github/team22/
# Out:
# /home/jupyter-andromary/github/team22
# /opt/tljh/user/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !git checkout main
# Out:
# Switched to branch 'main'
# Your branch is up to date with 'origin/main'.

# %%
# !git pull
# Out:
# Already up to date.

# %%
import csv

with open("/home/jupyter-andromary/github/team22/library/streams/2024/hw_status.csv", newline = '') as hw_status:
    reader = csv.reader(hw_status)
    for row in reader:
        print(row)
        # find list[0] ='Andromary'
# Out:
# ['login in github', 'home folder in project', 'hw-1', 'hw-2', 'hw-3', 'hw-4', 'hw-5', 'hw-6', 'hw-7', 'hw-8', 'hw-9', 'hw-11', 'hw-12', 'hw-13', 'hw-14', 'hw-15', 'hw-16', 'hw-17', 'hw-18', 'hw-19', 'hw-20', 'hw-21', 'hw-22', 'hw-23', 'hw-24', 'hw-25', 'hw-26', 'hw-27', 'hw-28', 'hw-29', 'hw-30']
# ['22malvina', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['AAEltsov', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['AAKesareva', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['ADBukreev', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['ADKazdym', '', '95%', '100%', '100%', '100%', '55', '0', '0', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ...

# %%
my_data = "{'27-03-2024': '1', '03-04-2024': '1'}"
data_list = my_data.split(",")
print(data_list)
# Out:
# ["'27-03-2024': '1'", " '03-04-2024': '1'"]

# %%
import json
my_data = '{'27-03-2024': '1', '03-04-2024': '1'}'
d = json.loads(my_data)
print(d)
# Out:
#   Cell In[12], line 2
#     my_data = '{'27-03-2024': '1', '03-04-2024': '1'}'
#                     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
for item in data_list:

# %%
n = 3
d = dict(input().split(",") for _ in range(n))
print (d)
# Out:
#  27-03-2024 1, 03-04-2024 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 n = 3
# ----> 2 d = dict(input().split(",") for _ in range(n))
#       3 print (d)
#
# Cell In[9], line 2, in <genexpr>(.0)
#       1 n = 3
# ----> 2 d = dict(input().split(",") for _ in range(n))
#       3 print (d)
#
# File /opt/tljh/user/lib/python3.10/site-packages/ipykernel/kernelbase.py:1270, in Kernel.raw_input(self, prompt)
#    1268     msg = "raw_input was called, but this frontend does not support input requests."
#    1269     raise StdinNotImplementedError(msg)
# -> 1270 return self._input_request(
#    1271     str(prompt),
#    1272     self._parent_ident["shell"],
#    1273     self.get_parent("shell"),
#    1274     password=False,
#    1275 )
#
# ...
