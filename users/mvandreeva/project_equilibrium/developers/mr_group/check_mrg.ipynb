# %%
from mr_group_parsing import MRGroupParser, MRGroupParserFFile

# %%
text = ""
with open("sources/mrgroup", "rb") as response:
    text = response.read()

flats_data = MRGroupParserFFile(text)
flats_dict_list = flats_data.get_dict_list()
for item in flats_dict_list:
    data_list = get_params
    for data in data_list:
        assert data in item.keys()
# Out:
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [1, 2025]
# 2025
# [1, 2025]
# 2025
# [1, 2025]
# 2025
# [1, 2025]
# 2025
# [1, 2025]
# 2025
# [1, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2025
# [2, 2025]
# 2023
# [4, 2023]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# 2024
# [1, 2024]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 8
#       6 flats_dict_list = flats_data.get_dict_list()
#       7 for item in flats_dict_list:
# ----> 8     data_list = get_params
#       9     for data in data_list:
#      10         assert data in item.keys()
#
# NameError: name 'get_params' is not defined
