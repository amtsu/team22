# %%
from bs4 import BeautifulSoup
import urllib
import urllib.request

from lsr_parsing import LSRParser

# %%
url = "https://www.lsr.ru/msk/kvartiry-v-novostroikah/?price%5Bmin%5D=&price%5Bmax%5D=&area%5Bmin%5D=&area%5Bmax%5D=&floor%5Bmin%5D=&floor%5Bmax%5D=&last_delivery=30&mortgage_type=&mortgage_payment=&mortgage_time=&__s=&ob%5Bpage%5D=1&ob%5Bid%5D=52&ob%5Bsort%5D=price&ob%5Border%5D=asc&a=flats&object=52&__s="

with urllib.request.urlopen(url) as page:
    lsr_page = page.read()
print(lsr_page)
# lsr = LSRParser(url)
# project_name = "ДМИТРОВСКОЕ НЕБО"
# address = lsr.get_address(project_name)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /opt/tljh/user/lib/python3.9/urllib/request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File /opt/tljh/user/lib/python3.9/http/client.py:1279, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1278 """Send a complete request to the server."""
# -> 1279 self._send_request(method, url, body, headers, encode_chunked)
#
# File /opt/tljh/user/lib/python3.9/http/client.py:1325, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1324     body = _encode(body, 'body')
# ...
