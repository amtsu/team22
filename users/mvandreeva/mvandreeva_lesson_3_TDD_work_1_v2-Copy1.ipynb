# %% [markdown]
# # Отработка работы с переменными и списками V2

# %% [markdown]
# # №1 Задание создайте 3 списока
# <center>
#     <table>
#         <tr>
#             <td>
#                 списоки
#             </td>
#             <td>
#                 Дело №1
#             </td>
#             <td>
#                 Дело №2
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 дела
#             </td>
#             <td>
#                 купить хлеб
#             </td>
#             <td>
#                 помыть полы
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 дата до котрой нужно сделать
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 дата когда было сделано
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#             <td>
#             </td>
#         </tr>
#     </table>
# </center>
#
# Рекомендуемый размер списка 22 элемента.
#
# После создания 3 списков.
# * Нужно посчитать общее количество дел в списке.
# * Напечатать все дела
# * Напечатать только 2 и 5 дело
# * Сравнить каждое дело из списка с строкой “buy bread”  и если оно совпадает то напечатать YES
# * Если каждое дело из списка ваших дела написано на английском и является строкой то вывести длину каждой из этих строк
# * Напечатать yes если длина строки в которой записано дело больше 10
# * Напечатать дела индекс которых в списке делится без остатка на 2
# * Напечатать дело с индексом 1 и 4 из списка запланированных дел
# * Напечатать те индексы у которых значения в списке запланированных дат и списке реализованных дат равны друг другу
# * Вывести только те дела которые вы сделали в тот же день в который их запланировали
# * Посчитать сколько дел у вас было одинаковых ( т.е. если есть запись “купить хлеб” 28-08-2022 и “купить хлеб” 14-08-2022 то финально нужно вывести “купить хлеб” 2 (можно сделать 2 варианта без использования словарей и с испольщованием словарям)

# %%
to_do_list = [ 'child to kindergarden','watch film','call friend', 'walk with children','buy products', 'cook meals','walk with children', 'wash floor','buy products', 'wash clothes','walk with children','buy products', 'cook meals','walk with children', 'cook meals','play with children', 'sleep','walk with dog', 'buy products','prepare hometask on python', 'child to kindergarden', 'cook meals']
deadline = ['30-08-2022', '30-08-2022', '30-08-2022', '01-09-2022', '01-09-2022', '01-09-2022', '03-09-2022', '03-09-2022',  '03-09-2022', '05-09-2022', '05-09-2022', '06-09-2022', '06-09-2022', '06-09-2022', '07-09-2022', '07-09-2022', '07-09-2022', '08-09-2022', '08-09-2022', '08-09-2022', '08-09-2022', '08-09-2022']
finish_date = ['28-09-2022', '30-08-2022', '30-08-2022', '01-09-2022', '29-08-2022', '01-09-2022', '02-09-2022', '03-09-2022',  '03-09-2022', '04-09-2022', '05-09-2022', '05-09-2022', '06-09-2022', '06-09-2022', '06-09-2022', '07-09-2022', '07-09-2022', '07-09-2022', '08-09-2022', '08-09-2022', '09-09-2022', '08-09-2022']
#-----------------------------------------------------------
#посчитать общее количество дел в списке
print(type(to_do_list))

def count_elements(list_for_check):
    if isinstance(list_for_check, list):
        result = len(list_for_check)
        return result
    else:
        print 'type is not a list', type(list_for_check)
    print '-----------------------------------------------------------'

print count_elements(to_do_list)
print '-----------------------------------------------------------'

def test_1():
    if count_elements(['child to kindergarden','watch film','call friend', 'walk with children','buy products', 'cook meals']) == 6:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'

def test_2():
    if count_elements([ 'child to kindergarden','watch film','call friend']) == 3:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
    
def test_3():
    if count_elements(10) == 2:
        print 'passed'
    else:
        print 'FAILED'
        
def test_all():
    test_1()
    test_2()
    test_3()
    print('all tests cheked')
    
test_all()
# Out:
# <type 'list'>
# 22
# -----------------------------------------------------------
# passed
# -----------------------------------------------------------
# passed
# -----------------------------------------------------------
# type is not a list <type 'int'>
# -----------------------------------------------------------
# FAILED
# all tests cheked

# %%
#Напечатать все дела
def print_elements(list_for_check):
    if isinstance(list_for_check, list):
        result = []
        for element in list_for_check:
            print element
            result.append(element)
        return result
    else:
        print 'type is not a list', type(list_for_check)

print(print_elements(['child to kindergarden','watch film','call friend']))
print '-----------------------------------------------------------'

def test_1():
    if print_elements(['child to kindergarden','watch film','call friend']) == ['child to kindergarden','watch film','call friend']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'

def test_2():
    if print_elements(['call friend', 'walk with children','buy products', 'cook meals']) == ['call friend', 'walk with children','buy products', 'cook meals']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
def test_3():
    if print_elements([]) == []:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
def test_4():
    if print_elements(['walk with children']) == ['walk with children']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
def test_5():
    if print_elements('walk with children') == ['walk with children']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'

def test_all():
    test_1()
    test_2()
    test_3()
    print('all tests cheked')
  
test_all()
# Out:
# child to kindergarden
# watch film
# call friend
# ['child to kindergarden', 'watch film', 'call friend']
# -----------------------------------------------------------
# child to kindergarden
# watch film
# call friend
# passed
# -----------------------------------------------------------
# call friend
# walk with children
# buy products
# cook meals
# passed
# -----------------------------------------------------------
# passed
# -----------------------------------------------------------
# all tests cheked

# %%
def print_2_5(list_for_check):
    result = []
    if len(list_for_check) >= 5:
        result.append(list_for_check[1])
        result.append(list_for_check[4])
    else:
        print 'the list is too short'
    print result
    return result

# %%
def test_1():
    if print_2_5(['child to kindergarden','watch film','call friend', 'walk with children','buy products', 'cook meals']) == ['watch film', 'buy products']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
#test_1()

def test_2():
    if print_2_5(['child to kindergarden', 'walk with children','buy products', 'cook meals', 'child to kindergarden']) == ['walk with children', 'child to kindergarden']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
#test_2()

def test_3():
    if print_2_5(['child to kindergarden', 'watch film','buy products', 'call friend', 'cook meals']) != ['watch film', 'cook meals']:
        assert False
    print '-----------------------------------------------------------'
    
#test_3()

def test_4():
    if print_2_5(['walk with children','watch film']) == ['walk with children','watch film']:
        assert False
    print '-----------------------------------------------------------'
    
test_4()

def test_all():
    test_1()
    test_2()
    test_3()
    test_4()
    print('all tests cheked')
  
test_all()
# Out:
# the list is too short
# []
# -----------------------------------------------------------
# ['watch film', 'buy products']
# passed
# -----------------------------------------------------------
# ['walk with children', 'child to kindergarden']
# passed
# -----------------------------------------------------------
# ['watch film', 'cook meals']
# -----------------------------------------------------------
# the list is too short
# []
# -----------------------------------------------------------
# all tests cheked

# %%
#Сравнить каждое дело из списка с строкой “buy bread” и если оно совпадает то напечатать YES
def is_buy_bread(list_for_check):
    for element in list_for_check:
        if element == 'buy bread':
            return 'YES'

# %%
def test_1():
    if is_buy_bread(['buy bread', 'walk with children']) == 'YES':
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
test_1()

def test_2():
    if is_buy_bread(['buy bread', 'walk with children']) != 'YES':
        assert False
    print '-----------------------------------------------------------'
                 
test_2()

def test_all():
    test_1()
    test_2()
    print('all tests cheked')
  
test_all()
# Out:
# passed
# -----------------------------------------------------------
# -----------------------------------------------------------
# passed
# -----------------------------------------------------------
# -----------------------------------------------------------
# all tests cheked

# %%
#Если каждое дело из списка ваших дела написано на английском и является строкой то вывести длину каждой из этих строк
def display_elements_len(list_for_check):
    #import re
    result = []
    for element in list_for_check:
        if isinstance(element, str):
            #if re.match([^a-z$]i, element):
            print len(element)
            result.append(len(element))
    if result == []:
        print "elements in list are not of type 'str'"
    print result
    return result

# %%
def test_1():
    if display_elements_len(['bread', 'milk']) == [5, 4]:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
#test_1()  

def test_2():
    if display_elements_len(['soap', 'rope']) == [4, 4]:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
#test_2() 

def test_3():
    if display_elements_len([21, 'rope']) != [4]:
        assert False 
    print '-----------------------------------------------------------'
                 
#test_3() 

def test_4():
    if display_elements_len([21, 365]) != []:
        assert False 
    print '-----------------------------------------------------------'
                 
#test_4()

def test_all():
    test_1()
    test_2()
    test_3()
    test_4()
    print('all tests cheked')
  
test_all()
# Out:
# 5
# 4
# [5, 4]
# passed
# -----------------------------------------------------------
# 4
# 4
# [4, 4]
# passed
# -----------------------------------------------------------
# 4
# [4]
# -----------------------------------------------------------
# elements in list are not of type 'str'
# []
# -----------------------------------------------------------
# all tests cheked

# %%
#Напечатать yes если длина строки в которой записано дело больше 10
def does_exceed_10(list_for_check):
    for element in list_for_check:
        if len(element) > 10:
            print 'yes'
            return 'yes'

# %%
def test_1():
    if does_exceed_10(['buy bread', 'walk with children']) == 'yes':
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
#test_1() 

def test_2():
    if does_exceed_10(['buy bread', 'walk']) == None:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
#test_2() 

def test_all():
    test_1()
    test_2()
    print('all tests cheked')
  
test_all()
# Out:
# yes
# passed
# -----------------------------------------------------------
# passed
# -----------------------------------------------------------
# all tests cheked

# %%
#Напечатать дела индекс которых в списке делится без остатка на 2
def div_index_2(list_for_check):
    result = []
    for i in range(len(list_for_check)):
        if i % 2 == 0:
            print list_for_check[i]
            result.append(list_for_check[i])
    return result

# %%
def test_1():
    if div_index_2(['child to kindergarden','watch film', 'walk with children']) == ['child to kindergarden', 'walk with children']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
test_1()  

def test_2():
    if div_index_2([]) != []:
        assert False 
    print '-----------------------------------------------------------'
                 
test_2()
# Out:
# child to kindergarden
# walk with children
# passed
# -----------------------------------------------------------
# -----------------------------------------------------------

# %%
#Напечатать дело с индексом 1 и 4 из списка запланированных дел
def print_index_1_4(list_for_check):
    result = []
    if len(list_for_check) >= 5:
        result.append(list_for_check[1])
        result.append(list_for_check[4])
    else:
        print 'the list is too short'
    print result
    return result

# %%
def test_1():
    if print_2_5(['child to kindergarden','watch film','call friend', 'walk with children','buy products', 'cook meals']) == ['watch film', 'buy products']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
#test_1()

def test_2():
    if print_2_5(['child to kindergarden', 'walk with children','buy products', 'cook meals', 'child to kindergarden']) == ['walk with children', 'child to kindergarden']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
#test_2()

def test_3():
    if print_2_5(['child to kindergarden', 'watch film','buy products', 'call friend', 'cook meals']) != ['watch film', 'cook meals']:
        assert False
    print '-----------------------------------------------------------'
    
#test_3()

def test_4():
    if print_2_5(['walk with children','watch film']) == ['walk with children','watch film']:
        assert False
    print '-----------------------------------------------------------'
    
test_4()

def test_all():
    test_1()
    test_2()
    test_3()
    test_4()
    print('all tests cheked')
  
test_all()
# Out:
# the list is too short
# []
# -----------------------------------------------------------
# ['watch film', 'buy products']
# passed
# -----------------------------------------------------------
# ['walk with children', 'child to kindergarden']
# passed
# -----------------------------------------------------------
# ['watch film', 'cook meals']
# -----------------------------------------------------------
# the list is too short
# []
# -----------------------------------------------------------
# all tests cheked

# %%
#Напечатать те индексы у которых значения в списке запланированных дат и списке реализованных дат равны друг другу
to_do_list = [ 'child to kindergarden','watch film','call friend', 'walk with children']
deadline = ['30-08-2022', '30-08-2022', '30-08-2022', '01-09-2022']
finish_date = ['28-09-2022', '30-08-2022', '30-08-2022', '01-09-2022']
def display_done_as_planned(to_do_list, deadline, finish_date):
    result = []
    for i in range(0, len(to_do_list)):
        if deadline[i] == finish_date[i]:
            print(to_do_list[i])
            result.append(to_do_list[i])
    return result

# %%
def test_1():
    if display_done_as_planned(to_do_list, deadline, finish_date) == ['watch film','call friend', 'walk with children']:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
test_1()

def test_2():
    if display_done_as_planned(to_do_list, deadline, finish_date) != ['watch film','call friend', 'walk with children']:
        assert False
    print '-----------------------------------------------------------'
                 
test_2()
# Out:
# watch film
# call friend
# walk with children
# passed
# -----------------------------------------------------------
# watch film
# call friend
# walk with children
# -----------------------------------------------------------

# %%
#Посчитать сколько дел у вас было одинаковых ( т.е. если есть запись “купить хлеб” 28-08-2022 и “купить хлеб” 14-08-2022 то финально нужно вывести “купить хлеб” 2 (можно сделать 2 варианта без использования словарей и с испольщованием словарям)
def count_repeats(list_for_check):
    repeats = {}
    for deal in list_for_check:
        repeats[deal] = 0
        for i in range(0, len(list_for_check)):
            if list_for_check[i] == deal:
                repeats[deal] += 1
    result = {}            
    for key, value in repeats.items():
        if value > 1:
            print key, value
            result[key] = value
    return result

# %%
def test_1():
    if count_repeats(['watch film','call friend', 'watch film']) == {'watch film':2}:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
test_1()

def test_2():
    if count_repeats(['child to kindergarden','watch film','call friend', 'walk with children']) != {}:
        assert False
    print '-----------------------------------------------------------'
                 
test_2()
# Out:
# watch film 2
# passed
# -----------------------------------------------------------
# -----------------------------------------------------------

# %% [markdown]
# # №2 Задание создайте 2 списока
# <center>
#     <table>
#         <tr>
#             <td>
#                 списоки
#             </td>
#             <td>
#                 №1
#             </td>
#             <td>
#                 №2
#             </td>
#             <td>
#                 №3
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Описание
#             </td>
#             <td>
#                 купил хлеб
#             </td>
#             <td>
#                 купил тапочки
#             </td>
#             <td>
#                 получил зп
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Сумма
#             </td>
#             <td>
#                 -50
#             </td>
#             <td>
#                 -200
#             </td>
#             <td>
#                 50000
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Дата
#             </td>
#             <td>
#                 09-08-2022
#             </td>
#             <td>
#                 11-08-2022
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#         </tr>
#     </table>
# </center>
#
# * посчитайте сколько всего вы потратили за все время <br>
# *посчитать сколько трат было меньше 300 рублей<br>
# *посчитать сколько сумму трат которые были больше 10000 рублей<br>
# *выдать номера трат которые находятся в диапазоне между 300 и 10000 рублей<br>
# *выбрать из списка на втором шаге самую минимальную трату<br>
# *посчитать сколько трат было меньше 300 рублей<br>
# *посчитайте сколько заработали за все время<br>
# *посчитайте какие самые частые у вас траты(можно попробовать с использованием словарей)<br>
# *добавить к списку еще 3 действия<br>
# *Найти максимальную трату<br>
# *Найти минимальный доход<br>
# *Посчитать среднюю стоимость ваших трат<br>

# %%
#посчитайте сколько всего вы потратили за все время
def count_total_spendings(account_movements):
    spendings = 0
    for movement in account_movements:
        if movement < 0:
            spendings += movement
    return abs(spendings)

# %%
def test_1():
    if count_total_spendings([-50, -200, 50000]) == 250:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
test_1()

def test_2():
    if count_total_spendings([600, 10000, 50]) != 0:
        assert False
    print '-----------------------------------------------------------'
                 
test_2()
# Out:
# passed
# -----------------------------------------------------------
# -----------------------------------------------------------

# %%
#посчитать сколько трат было меньше 300 рублей
def count_spendings_less300(account_movements):

# %%
def test_1():
    if count_spendings_less300([-50, -200, 50000]) == 2:
        print 'passed'
    else:
        print 'FAILED'
    print '-----------------------------------------------------------'
                 
test_1()

def test_2():
    if count_total_spendings([600, 10000, 50]) != 0:
        assert False
    print '-----------------------------------------------------------'
                 
test_2()

# %% [markdown]
# # №3 Напишите функцию, которая перебирает числа от 1 до 15 (включительно) и возвращает список из чисел кратных 3.

# %% [markdown]
# # №4 Оформить каждый пункт из задания 1 и 2 в виде функции

# %% [markdown]
# # Пример ка кработать с словарями

# %%
slovar = {
    'home': 10,
    'car': 'volvo',
    'citis': ['Moscow', 'kazan', 'spb'],
    'notebook': {
        'memory': '100g',
        'cpu': 2,
    }
}

print(slovar)

print(slovar['notebook'])

slovar['temp'] = 'work'

print(slovar)

del slovar['citis']
print(slovar)

#keys
#values
#items

print(slovar.keys())

print(slovar.values())

print(slovar.items())

print('---')
for k, l in slovar.items():
    print('key =', k, ' value =', l)
# Out:
# {'home': 10, 'notebook': {'cpu': 2, 'memory': '100g'}, 'citis': ['Moscow', 'kazan', 'spb'], 'car': 'volvo'}
# {'cpu': 2, 'memory': '100g'}
# {'home': 10, 'notebook': {'cpu': 2, 'memory': '100g'}, 'citis': ['Moscow', 'kazan', 'spb'], 'temp': 'work', 'car': 'volvo'}
# {'home': 10, 'notebook': {'cpu': 2, 'memory': '100g'}, 'temp': 'work', 'car': 'volvo'}
# ['home', 'notebook', 'temp', 'car']
# [10, {'cpu': 2, 'memory': '100g'}, 'work', 'volvo']
# [('home', 10), ('notebook', {'cpu': 2, 'memory': '100g'}), ('temp', 'work'), ('car', 'volvo')]
# ---
# ('key =', 'home', ' value =', 10)
# ('key =', 'notebook', ' value =', {'cpu': 2, 'memory': '100g'})
# ('key =', 'temp', ' value =', 'work')
# ('key =', 'car', ' value =', 'volvo')
