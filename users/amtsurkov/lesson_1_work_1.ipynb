# %% [markdown]
# # Отработка работы с переменными и списками

# %% [markdown]
# # №1 Задание создайте 3 списока
# <center>
#     <table>
#         <tr>
#             <td>
#                 списоки
#             </td>
#             <td>
#                 Дело №1
#             </td>
#             <td>
#                 Дело №2
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 дела
#             </td>
#             <td>
#                 купить хлеб
#             </td>
#             <td>
#                 помыть полы
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 дата до котрой нужно сделать
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 дата когда было сделано
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#             <td>
#             </td>
#         </tr>
#     </table>
# </center>
#
# Рекомендуемый размер списка 22 элемента.
#
# После создания 3 списков.
# * Нужно посчитать общее количество дел в списке.
# * Вывести только те дела которые вы сделали в тот же день.
# * Посчитать сколько дел у вас было одинаковых ( т.е. если есть запись “купить хлеб” 28-08-2022 и “купить хлеб” 14-08-2022 то финально нужно вывести “купить хлеб” 2

# %% [markdown]
# # №2 Задание создайте 2 списока
# <center>
#     <table>
#         <tr>
#             <td>
#                 списоки
#             </td>
#             <td>
#                 №1
#             </td>
#             <td>
#                 №2
#             </td>
#             <td>
#                 №3
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Описание
#             </td>
#             <td>
#                 купил хлеб
#             </td>
#             <td>
#                 купил тапочки
#             </td>
#             <td>
#                 получил зп
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Сумма
#             </td>
#             <td>
#                 -50
#             </td>
#             <td>
#                 -200
#             </td>
#             <td>
#                 50000
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Дата
#             </td>
#             <td>
#                 09-08-2022
#             </td>
#             <td>
#                 11-08-2022
#             </td>
#             <td>
#                 28-08-2022
#             </td>
#         </tr>
#     </table>
# </center>
#
# * посчитайте сколько всего вы потратили за все время
# * посчитайте сколько заработали за все время
# * посчитайте какие самые частые у вас траты

# %% [markdown]
# # №3 Напишите функцию, которая перебирает числа от 1 до 15 (включительно) и возвращает список из чисел кратных 3.

# %% [markdown]
# # №4 Оформить каждый пункт из задания 1 и 2 в виде функции
