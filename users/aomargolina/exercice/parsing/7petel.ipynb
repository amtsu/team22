# %%
import requests
from bs4 import BeautifulSoup
import re
import urllib
from urllib.request import urlopen
import csv

# %%
with open('eggs.csv', 'r', newline='') as csvfile:
...     spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
...     for row in spamreader:
...         print(', '.join(row))

# %%
for i in range(9):
    url = "https://www.7petel.ru/stitch/raskraski/dimensions?sort=default&page=" + str(i+1)
    response = urlopen(url)
    html = response.read().decode("utf-8")
    soup = BeautifulSoup(html, 'html.parser')
    items = soup.find_all('div', {'class': 'prod_blank'})
    #print(items)
    for item in items:
        color = item.find('div', {'class': 'prod_name'})
        price = item.find('div', {'class': 'prod_price'})
        print(color.text)
        print(price.text.strip())
        with open('7petel.txt', 'a', encoding='utf-8') as file:
            file.write(color.text)
            #file.write(price.text)
        with open('eggs.csv', 'w', newline='') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=' ',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
        spamwriter.writerow(['Spam'] * 5 + ['Baked Beans'])
        spamwriter.writerow(['Spam', 'Lovely Spam', 'Wonderful Spam'])
        
    print('*'*50)
# Out:
# Силуэты в сумерках
#
# 1837 руб.
#
# Бабочка
#
# 1051
# 788 руб.
#
# Яркая собака
#
# 981 руб.
#
# Колибри и гибискус
#
# 1837 руб.
#
# Сова среди цветов
#
# 1012 руб.
#
# Зимняя тишина
#
# 2954 руб.
#
# Вид на Темзу
#
# 2683 руб.
#
# Маяк на восходе
#
# 1975
# 1876 руб.
#
# Мудрая сова
#
# 1837 руб.
#
# Сигнальная башня в сумерках
#
# 3175
# 3016 руб.
#
# Каное около озера
#
# 2954
# 2806 руб.
#
# Кафе у моря
#
# 1837
# 1745 руб.
#
# Ракушки
#
# 1975
# 1876 руб.
#
# Золотистые ретриверы
#
# 2954
# 2806 руб.
#
# Дикие перья
#
# 1837 руб.
#
# {{name}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 12
#      10 price = item.find('div', {'class': 'prod_price'})
#      11 print(color.text)
# ---> 12 print(price.text.strip())
#      13 with open('7petel.txt', 'a', encoding='utf-8') as file:
#      14     file.write(color.text)
#
# ...

# %%
<div class="prod_blank">
	<div class="prod_name">
        <a href="/vyshivka/dimensions/73-91612" title="Dimensions Лесная чародейка"><b style="line-height:12px;">Лесная чародейка</b></a>
	</div>
	<p class="prod_art">
		Арт. <b>73-91612</b>
	</p>				
	<div class="prod_image">
            
		<a onmouseover="HideShowDiv('divProduct108811', true)" onmouseout="HideShowDiv('divProduct108811', false)" href="/vyshivka/dimensions/73-91612" title="Перейти на страницу товара"><img src="/pictures/m/73-91612.jpg" alt="Лесная чародейка" onload="MoveResizeDiv('divProduct108811', this);"></a>
		
		<div id="divProduct108811" style="width: 34px; height: 34px; z-index: 2; position: relative; top: -39px; display: none; left: 146px;">
		<a onmouseover="HideShowDiv('divProduct108811', true)" onmouseout="HideShowDiv('divProduct108811', false)" href="" onclick="return ExpandHs(this, '/pictures/l/73-91612.jpg');" title="Увеличить картинку">
		<img class="zoom_img" src="/highslide/graphics/fullexpand.gif">
		</a>
		</div>		
		
		
	</div>
	<p>
        
		<a href="" onclick="return ExpandHs(this, '/pictures/l/73-91612.jpg');">					
			<img src="/highslide/graphics/zoom.png" alt="" style="margin-top: 1px;"></a>		
		Dimensions
	</p>			
	<p class="prod_desc">
		
		Техника: Раскраски
		
        
	</p>	
	
	<p class="prod_desc">
		
		Размер: 50.8x35.5 см
		
	</p>		
	
	
	
		
	<table width="100%">
	<tbody><tr><td style="width: 23px;">
        <a href="#" id="wishlist-toggle-108811" class="wishlist-toggle" onclick="ShowWishlistDialog('divWishlist', this, 108811, 'Лесная чародейка', '73-91612', '73-91612', 'Dimensions', 'Раскраски', '50.8x35.5'); return false;"></a>
    </td><td style="border:0px;">
	<div style="height:23px;margin-left:15px;margin-right:10px;">
	<div style="color: red; font-weight: bold; font-size: 12px;">        
        Нет в наличии</div>	
    <div style="position: relative; top: -7px;"><a href="" style="font-size: 12px;" onclick="ShowReminderDialog('divReminder', this, 108811, 'Лесная чародейка', '73-91612', '73-91612', 'Dimensions', 'Раскраски', '50.8x35.5'); return false;">Сообщить когда появится</a></div>
	</div>
	</td><td style="width: 15px;">
        &nbsp;
    </td></tr>
	</tbody></table>
	<div>
	
	</div>
		
	
		
	
	<div class="prod_price">
		
		
		

        
		<b>2628</b> руб.
        				
	</div>				
</div>
