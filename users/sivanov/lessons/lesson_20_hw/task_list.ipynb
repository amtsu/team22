# %%
#поехали первое задание
#from sivanov_lib.mylistdata import MyTaskList
import sivanov_lib
from sivanov_lib.mylistdata import files_work
from sivanov_lib.mylistdata import work

# %%
files_work()
# Out:
# --------------------------------1-----------------------------------------
# begin testing
# ---append(buy bread,5-2-2022)---2--show()---------------------------------
#     1 : |                 buy bread |   5-2-2022 |            |
#
# --------------------------------3-----------------------------------------
# --append-some-data--------------4--set_all_actions_done-show()------------
#     1 : |                 buy bread |   5-2-2022 |   1-3-2022 |
#     2 : |                   buy car |  12-2-2022 |   2-3-2022 |
#     3 : |                    go jym |  23-2-2022 |   3-3-2022 |
#     4 : |                   поспать |  24-2-2022 |   4-3-2022 |
#
# -save_to_json-clear()-show()----5-----------------------------------------
#
# -----load_from_json---show()----6---show()--------------------------------
#     1 : |                 buy bread |   5-2-2022 |   1-3-2022 |
#     2 : |                   buy car |  12-2-2022 |   2-3-2022 |
# ...

# %%
# !cat ./json/base_actions.json
# Out:
# [["buy bread", "5-2-2022", "1-3-2022"], ["buy car", "12-2-2022", "2-3-2022"], ["go jym", "23-2-2022", "3-3-2022"], ["\u043f\u043e\u0441\u043f\u0430\u0442\u044c", "24-2-2022", "4-3-2022"]]

# %%
# !cat ./pickle/task_list.pickle
# Out:
# 	12-2-2022h
# 	23-2-2022h
# 	24-2-2022h
# 	24-2-2022h
# ube.

# %%
work()
# Out:
# begin HW
# --------------------------------1-----------------------------------------
# Нужно посчитать общее количество дел в списке.
# Всего дел в списке : 21.
# --------------------------------2-----------------------------------------
# Напечатать все дела
#     1 : |                 buy bread |   5-3-2022 |   1-3-2022 |
#     2 : |                 buy bread |  10-3-2022 |   2-3-2022 |
#     3 : |              промыть полы |   2-3-2022 |   3-3-2022 |
#     4 : |              промыть полы |   4-3-2022 |   4-3-2022 |
#     5 : |              промыть полы |   6-3-2022 |   5-3-2022 |
#     6 : |              промыть полы |   8-3-2022 |   6-3-2022 |
#     7 : |              промыть полы |  10-3-2022 |   7-3-2022 |
#     8 : |              промыть полы |  12-3-2022 |   8-3-2022 |
#     9 : |               купить хлеб |   3-3-2022 |   9-3-2022 |
#    10 : |               купить хлеб |   6-3-2022 |  10-3-2022 |
#    11 : |               купить хлеб |   9-3-2022 |  11-3-2022 |
# ...

# %%
#всё, спать.
